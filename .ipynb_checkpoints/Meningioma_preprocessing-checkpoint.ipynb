# %% [markdown]
# # Preprocessing brain MRI of patients with meningioma

# %% [markdown]
# ## Before using MONSTR
#
# ### Setting PATH variable
# **The environment PATH MUST be set in the main terminal, not otherwise like in a sub-terminal in the Jupyterlab**
#
# #### ANTs
# export ANTSPATH=/opt/ANTs/bin/
#
# export PATH=${ANTSPATH}:$PATH
#
# #### FSL
# FSLDIR=/usr/local/fsl
# . ${FSLDIR}/etc/fslconf/fsl.sh
#
# PATH=${FSLDIR}/bin:${PATH}
#
# export FSLDIR PATH

# %% [markdown]
# ### Update
# 6/22 \
# Code that applies brain mask added.
#
# 6/23 \
# New variable T1C_label added\
# (Sometimes you might want to do co-registration to sequence other than T1C, but this time we assume that you are  registering other sequences to T1C.)\
#
# 7/6 \
# New variable mask_label added
#
# 7/7 \
# Add try-except when finding T1Cpath and T2path using glob since T1C and T2 file might not exist
#
# ### Note
# error \
# terminate called after throwing an instance of 'std::invalid_argument'
#
#   what():  stoi
#
# Aborted (core dumped)
#
# ==> due to space in filename
#
# ### to-do
# get pt and seq using re function
# add pipeline process would be better

# %%
import os
import shutil
import nibabel as nib
import numpy as np
from glob import glob

# %%
# make outputdir and return output path by combining outDir, pt, filename
def get_outpath(outDir, pt, filename):
    outPath = os.path.join(outDir, pt, filename)
    os.makedirs(os.path.join(outDir, pt), exist_ok=True)

    if os.path.exists(outPath):
        print('{} already exists'.format(filename))
        return None
    else:
        return outPath

# find sequence from filename
def find_seq(filename):
    seq_lst = ["T1_GD", "T1GD", "T1CE", "T1C", "CT1", "T1", "T2F", "3D_FLAIR", "FLAIRGD", "FLAIR", "T2", "F", "ADC", "BB", "WB"]
    seq = None
    for i in seq_lst:
        if i in filename.upper():
            seq = i
            return seq
    if seq is None:
        print("No matching sequence")
        return None

# %%
#sourceDir = '/media/sc-mlsg/easystore/KHS_control_nii_sorted/'
#targetDir = '/media/sc-mlsg/easystore/KHS_control_nii_sorted_preprocessed/'

sourceDir = '/home/sc-mlsg/Downloads/Meningioma_nii/'
targetDir = '/home/sc-mlsg/Downloads/Meningioma_nii_preprocessed/'

resampleDir_mask = os.path.join(targetDir, "00_Tumor_masks_resampled")
#registerDir_mask = os.path.join(targetDir, "00_Tumor_masks_registered")
resampleDir = os.path.join(targetDir, "01_Resampled")
correctionDir = os.path.join(targetDir, "02_Corrected")
registerDir = os.path.join(targetDir, '03_Registered_corrected')
brainmaskDir = os.path.join(targetDir, 'BrainMask_corrected')
strippedDir = os.path.join(targetDir, '04_Stripped_wo_Normalized')
znormedDir = os.path.join(targetDir, '05_Stripped_znormalized')

path_lst = [resampleDir, correctionDir, registerDir, brainmaskDir, strippedDir, znormedDir, resampleDir_mask]

for path in path_lst:
    os.makedirs(path, exist_ok=True)

T1C_label = 'T1C' # 'BB','T1C','T1GD' etc.
mask_label = 'mask' # '_mask', '-label' etc.

# %%
# check directory structure
for (path, dirs, files) in os.walk(sourceDir):
    print(path, dirs, files)
# Out:
# /home/sc-mlsg/Downloads/Meningioma_nii/ ['8155858', '7040064', '7350798'] []
# /home/sc-mlsg/Downloads/Meningioma_nii/8155858 [] ['8155858_T1C.nii.gz', '8155858_T2.nii.gz']
# /home/sc-mlsg/Downloads/Meningioma_nii/7040064 [] ['7040064_T1C.nii.gz', '7040064_T2.nii.gz']
# /home/sc-mlsg/Downloads/Meningioma_nii/7350798 [] ['7350798_T1C.nii.gz', '7350798_T2.nii.gz']

# %%
# check file orientation
for (path, dirs, files) in os.walk(sourceDir):
    if files != []:
        for file in files:
            # load img
            img = nib.load(os.path.join(path, file))
            if nib.aff2axcodes(img.affine) != ('L', 'P', 'S'):
                print(file)
                print(nib.aff2axcodes(img.affine))

# %%
# 1) resampling
lst = ['postprocessing.json', 'volumes.txt', 'segmentation.nii.gz'] #,mask.nii.gz]
total = 0
for (path, dirs, files) in os.walk(sourceDir):
    if not dirs:
        for file in files:
            if file not in lst:
                total += 1
                print("Resampling: #{}, {}".format(total, file))
                filePath = os.path.join(path, file)
                pt = path.split(os.path.sep)[-1]
                if mask_label in file:
                    pt = path.split(os.path.sep)[-1]
    #                pt = file.split("_")[0]
                    resample_outPath = get_outpath(resampleDir_mask, pt, file)
                else:
                    resample_outPath = get_outpath(resampleDir, pt, file)

                if resample_outPath is None:
                    continue
                # !ResampleImage 3 {filePath} {resample_outPath} 1x1x1
# Out:
# Resampling: #1, 8155858_T1C.nii.gz
# Resampling: #2, 8155858_T2.nii.gz
# Resampling: #3, 7040064_T1C.nii.gz
# Resampling: #4, 7040064_T2.nii.gz
# Resampling: #5, 7350798_T1C.nii.gz
# Resampling: #6, 7350798_T2.nii.gz

# %%
# 2) N4 bias correction
total = 0
for (path, dirs, files) in os.walk(resampleDir):
    for file in files:
        total += 1
        print("N4 bias correction: #{}, {}".format(total, file))
        filePath = os.path.join(path, file)
        pt = path.split(os.path.sep)[-1]
        corr_outPath = get_outpath(correctionDir, pt, file)
        if corr_outPath is None:
            continue
        # !N4BiasFieldCorrection -d 3 -i {filePath} -o {corr_outPath} -s 3 -c [50x50x50x50,0.00001] -b [150]
# Out:
# N4 bias correction: #1, 8155858_T1C.nii.gz
# N4 bias correction: #2, 8155858_T2.nii.gz
# N4 bias correction: #3, 7040064_T1C.nii.gz
# N4 bias correction: #4, 7040064_T2.nii.gz
# N4 bias correction: #5, 7350798_T1C.nii.gz
# N4 bias correction: #6, 7350798_T2.nii.gz

# %%
# 3) co-registration
total = 0
for (path, dirs, files) in os.walk(correctionDir):
    if files != []:
        total += 1
        print("coregistration: #{}, {}".format(total, files))
        pt = path.split(os.path.sep)[-1]
        
        try:
            T1C_path = glob(os.path.join(path, '*{}*'.format(T1C_label)))[-1]
        except:
            print("Target sequence not exists")
            continue
        T1C_regist_outPath = get_outpath(registerDir, pt, pt + '_{}_registered.nii'.format(T1C_label))
        if os.path.splitext(T1C_path)[-1] == '.gz':
            T1C_regist_outPath = get_outpath(registerDir, pt, pt + '_{}_registered.nii.gz'.format(T1C_label))

        if T1C_regist_outPath is not None:
            shutil.copyfile(T1C_path, T1C_regist_outPath)
        
        for file in files:
            seq = find_seq(file)
            if seq == T1C_label:
                continue
            in_path = os.path.join(path, file)
            print("Registering {} to {}...".format(seq, T1C_label))
            outPath = get_outpath(registerDir, pt, pt + '_{}_registered.nii.gz'.format(seq))
            if outPath is None:
                continue

            # !antsRegistration -d 3 -r [{T1C_path}, {in_path}, 1] \
                              -m mattes[{T1C_path}, {in_path}, 1, 32, regular, 0.1 ] \
                              -t translation[0.1] -c [100x50x25,1.e-8,20] -s 4x2x1vox -f 6x4x2 -l 1 \
                              -m mattes[{T1C_path}, {in_path} , 1 , 32, regular, 0.1] \
                              -t rigid[0.1] -c [100x50x25,1.e-8,20]  -s 4x2x1vox  -f 3x2x1 -l 1 -o [reg, {outPath}] -v 0
# Out:
# coregistration: #1, ['8155858_T1C.nii.gz', '8155858_T2.nii.gz']
# Registering T2 to T1C...
# coregistration: #2, ['7040064_T1C.nii.gz', '7040064_T2.nii.gz']
# Registering T2 to T1C...
# coregistration: #3, ['7350798_T1C.nii.gz', '7350798_T2.nii.gz']
# Registering T2 to T1C...

# %%
# 3) co-registration: mask(optional)
total = 0
for (path, dirs, files) in os.walk(resampleDir_mask):
    if files != []:
        total += 1
        print("coregistration: #{}, {}".format(total, files))
        pt = path.split(os.path.sep)[-1]

        try:
            T1C_path = glob(os.path.join(correctionDir, pt, '*{}*'.format(T1C_label)))[0]
        except:
            print("Target sequence not exists")
            continue
        print(T1C_path)
        for file in files:
            in_path = os.path.join(path, file)
            print("Registering mask to {}...".format(T1C_label))
            outPath = get_outpath(registerDir_mask, pt, file)
            if outPath is None:
                continue

            # !antsRegistration -d 3 -r [{T1C_path}, {in_path}, 1] \
                              -m mattes[{T1C_path}, {in_path}, 1, 32, regular, 0.1 ] \
                              -t translation[0.1] -c [100x50x25,1.e-8,20] -s 4x2x1vox -f 6x4x2 -l 1 \
                              -m mattes[{T1C_path}, {in_path} , 1 , 32, regular, 0.1] \
                              -t rigid[0.1] -c [100x50x25,1.e-8,20]  -s 4x2x1vox  -f 3x2x1 -l 1 -o [reg, {outPath}] -v 0
# Out:
# coregistration: #1, ['8011358_mask.nii']
# 8011358
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8011358/8011358_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #2, ['1371892_mask.nii']
# 1371892
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/1371892/1371892_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #3, ['2034571_mask.nii']
# 2034571
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/2034571/2034571_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #4, ['2174093_mask.nii']
# 2174093
# Target sequence not exists
# coregistration: #5, ['2545167_mask.nii']
# 2545167
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/2545167/2545167_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #6, ['2602057_mask.nii']
# 2602057
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/2602057/2602057_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #7, ['2826490_mask.nii']
# 2826490
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/2826490/2826490_T2F.nii
# Registering mask to T2F...
# coregistration: #8, ['3441152_mask.nii']
# 3441152
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/3441152/3441152_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #9, ['3692092_mask.nii']
# 3692092
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/3692092/3692092_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #10, ['3720122_mask.nii']
# 3720122
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/3720122/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #11, ['3893850_mask.nii']
# 3893850
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/3893850/3893850_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #12, ['5127114_mask.nii']
# 5127114
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/5127114/5127114_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #13, ['5329449_mask.nii']
# 5329449
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/5329449/5329449_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #14, ['5408861_mask.nii']
# 5408861
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/5408861/5408861_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #15, ['5786435_mask.nii']
# 5786435
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/5786435/5786435_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #16, ['6847146_mask.nii']
# 6847146
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/6847146/6847146_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #17, ['7354779_mask.nii']
# 7354779
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/7354779/7354779_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #18, ['7471985_mask.nii']
# 7471985
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/7471985/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #19, ['7731464_mask.nii']
# 7731464
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/7731464/7731464_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #20, ['7746738_mask.nii']
# 7746738
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/7746738/7746738_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #21, ['7926232_mask.nii']
# 7926232
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/7926232/7926232_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #22, ['8078358_mask.nii']
# 8078358
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8078358/8078358_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #23, ['8220926_mask.nii']
# 8220926
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8220926/8220926_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #24, ['8229739_mask.nii']
# 8229739
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8229739/8229739_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #25, ['8255367_mask.nii']
# 8255367
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8255367/8255367_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #26, ['8256132_mask.nii']
# 8256132
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8256132/8256132_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #27, ['8313277_mask.nii']
# 8313277
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8313277/8313277_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #28, ['8354455_mask.nii']
# 8354455
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8354455/8354455_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #29, ['8367857_mask.nii']
# 8367857
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8367857/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #30, ['8463790_mask.nii']
# 8463790
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8463790/8463790_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #31, ['8483143_mask.nii']
# 8483143
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8483143/8483143_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #32, ['8485609_mask.nii']
# 8485609
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8485609/8485609_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #33, ['8486052_mask.nii']
# 8486052
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8486052/8486052_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #34, ['8491797_mask.nii']
# 8491797
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8491797/8491797_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #35, ['8491887_mask.nii']
# 8491887
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8491887/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #36, ['8518093_mask.nii']
# 8518093
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8518093/8518093_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #37, ['8519762_mask.nii']
# 8519762
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8519762/8519762_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #38, ['8568702_mask.nii']
# 8568702
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8568702/8568702_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #39, ['8571328_mask.nii']
# 8571328
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8571328/8571328_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #40, ['8591024_mask.nii']
# 8591024
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8591024/8591024_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #41, ['8604413_mask.nii']
# 8604413
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8604413/8604413_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #42, ['8630035_mask.nii']
# 8630035
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8630035/8630035_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #43, ['8633978_mask.nii']
# 8633978
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8633978/8633978_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #44, ['8638813_mask.nii']
# 8638813
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8638813/8638813_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #45, ['8640861_mask.nii']
# 8640861
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8640861/8640861_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #46, ['8651745_mask.nii']
# 8651745
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8651745/8651745_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #47, ['8662383_mask.nii']
# 8662383
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8662383/8662383_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #48, ['8664725_mask.nii']
# 8664725
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8664725/8664725_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #49, ['8695364_mask.nii']
# 8695364
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8695364/8695364_T2F.nii.gz
# Registering mask to T2F...
# coregistration: #50, ['8739559_mask.nii']
# 8739559
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8739559/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #51, ['8747465_mask.nii']
# 8747465
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8747465/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #52, ['8806604_mask.nii']
# 8806604
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8806604/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #53, ['8822634_mask.nii']
# 8822634
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8822634/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #54, ['8841532_mask.nii']
# 8841532
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8841532/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #55, ['8845888_mask.nii']
# 8845888
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8845888/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #56, ['8849793_mask.nii']
# 8849793
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/8849793/T2F.nii.gz
# Registering mask to T2F...
# coregistration: #57, ['9019985_mask.nii']
# 9019985
# /media/sc-mlsg/Elements/20210322_IDHwtLGG_additional/Previous_patient/Severance_preprocessed/02_Corrected/9019985/T2F.nii.gz
# Registering mask to T2F...

# %%
# 4) Skull stripping using MONSTR

# we'll work in the MONSTR directory
workingDir = '/home/sc-mlsg/MONSTR'
# %cd {workingDir} 
outputPath = '/home/sc-mlsg/MONSTR/output'

T1_label = 'T1'
total = 0

for (path, dirs, files) in os.walk(registerDir):
    if files != []:
        total += 1
        print("skull stripping: #{}, {}".format(total, files))

        pt = path.split(os.path.sep)[-1]
        T1_path = sorted(glob(os.path.join(path, '*{}*'.format(T1_label))))[1]
        try:
            T2_path = glob(os.path.join(path, '*T2*'))[0]
        except:
            print("T2 not exists")
            T2_path = None
            
        newFileName = pt + '_brain_mask.nii.gz'
        if os.path.exists(os.path.join(brainmaskDir, newFileName)):
            print("{} already exists".format(newFileName))
            continue

        # !./MONSTR.sh --t1 {T1_path} --t2 {T2_path} --o {outputPath} --atlasdir TBI_atlas --reg

        newfile = glob(os.path.join(outputPath, '*pt*', 'atlas4_brainmask_ANTS.nii.gz'))
        shutil.copyfile(newfile, os.path.join(brainmaskDir, newFileName))

shutil.rmtree(outputPath)
# Out:
# /home/sc-mlsg/MONSTR
# skull stripping: #1, ['8155858_T1C_registered.nii.gz', '8155858_T2_registered.nii.gz', '8155858_T1_registered.nii.gz']
# I found ANTs installation at /opt/ANTs/bin
# Default number of atlases: 4
# Number of processors is not mentioned. Using all available 6 processors.
# Atlas directory : /home/sc-mlsg/MONSTR/TBI_atlas
# T1 : /home/sc-mlsg/Downloads/Meningioma_nii_preprocessed/03_Registered_corrected/8155858/8155858_T1_registered.nii.gz
# T2 : /home/sc-mlsg/Downloads/Meningioma_nii_preprocessed/03_Registered_corrected/8155858/8155858_T2_registered.nii.gz
# Output directory : /home/sc-mlsg/MONSTR/output
# Temporary files will be kept.
# Images are assumed to be registered. T2/PD/FLAIR will not be registered again to the T1.
# mktemp: failed to create directory via template ‘/home/sc-mlsg/MONSTR/output/8155858_T1_registered.nii.XXXX’: No such file or directory
# Working directory :
# cd
# ** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /home/sc-mlsg/t2.nii to FLOAT32
#      Warnings of this type will be muted for this session.
#      Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# Number of image modalities : 2
# N4BiasFieldCorrection -d 3 -i t1.nii -o t1.nii -s 3 -c [ 50x50x50x50,0.00001] -b [ 150]
# N4BiasFieldCorrection -d 3 -i t2.nii -o t2.nii -s 3 -c [ 50x50x50x50,0.00001] -b [ 150]
# AntsExample.sh t1.nii /home/sc-mlsg/MONSTR/TBI_atlas/atlas1_T1.nii fastfortesting atlas1_T1_ANTS.nii 6

# %%
# 5) apply skull mask
total = 0
error_dict = {}
for (path, dirs, files) in os.walk(registerDir):
    try:
        if files != []:
            total += 1
            pt = path.split(os.path.sep)[-1]
            maskName = pt + '_brain_mask.nii.gz'
            mask = nib.load(os.path.join(brainmaskDir, maskName))

            for file in files:
                seq = find_seq(file)
                print("# {} Applying skull mask to {}...".format(total, file))
                outPath = get_outpath(strippedDir, pt, pt + "_{}_stripped.nii.gz".format(seq))
                if outPath is None:
                    continue
                
                # Reshape (in some cases data resolution is (x,y,z,1), reshape removes the 4th dimension
                file_nii = nib.load(os.path.join(path, file))
                file_data = file_nii.get_data()
                file_data = file_data.reshape(file_data.shape[0], file_data.shape[1], file_data.shape[2])

                masked_data = np.multiply(file_data, mask.get_data())
                masked_data = nib.Nifti1Image(masked_data, file_nii.affine, file_nii.header)
                nib.save(masked_data, outPath)
    except Exception as ex:
        print("Error:{}, filename:{}".format(ex.args, file))
        error_dict[pt] = ex.args

print("Finished!")
print(error_dict)
# Out:
# # 1 Applying skull mask to 10000254_3D_FLAIR_registered.nii.gz...
# 10000254_3D_FLAIR_stripped.nii.gz already exists
# # 1 Applying skull mask to 10000254_BB_registered.nii.gz...
# 10000254_BB_stripped.nii.gz already exists
# # 1 Applying skull mask to 10000254_FLAIR_registered.nii.gz...
# 10000254_FLAIR_stripped.nii.gz already exists
# # 1 Applying skull mask to 10000254_T1_registered.nii.gz...
# 10000254_T1_stripped.nii.gz already exists
# # 1 Applying skull mask to 10000254_T2_registered.nii.gz...
# 10000254_T2_stripped.nii.gz already exists
# # 1 Applying skull mask to 10000254_WB_registered.nii.gz...
# 10000254_WB_stripped.nii.gz already exists
# # 2 Applying skull mask to 10004579_3D_FLAIR_registered.nii.gz...
# 10004579_3D_FLAIR_stripped.nii.gz already exists
# # 2 Applying skull mask to 10004579_BB_registered.nii.gz...
# 10004579_BB_stripped.nii.gz already exists
# # 2 Applying skull mask to 10004579_FLAIR_registered.nii.gz...
# 10004579_FLAIR_stripped.nii.gz already exists
# # 2 Applying skull mask to 10004579_T1_registered.nii.gz...
# 10004579_T1_stripped.nii.gz already exists
# # 2 Applying skull mask to 10004579_T2_registered.nii.gz...
# 10004579_T2_stripped.nii.gz already exists
# # 2 Applying skull mask to 10004579_WB_registered.nii.gz...
# 10004579_WB_stripped.nii.gz already exists
# # 3 Applying skull mask to 10010912_3D_FLAIR_registered.nii.gz...
# 10010912_3D_FLAIR_stripped.nii.gz already exists
# # 3 Applying skull mask to 10010912_BB_registered.nii.gz...
# 10010912_BB_stripped.nii.gz already exists
# # 3 Applying skull mask to 10010912_FLAIR_registered.nii.gz...
# 10010912_FLAIR_stripped.nii.gz already exists
# # 3 Applying skull mask to 10010912_T1_registered.nii.gz...
# 10010912_T1_stripped.nii.gz already exists
# # 3 Applying skull mask to 10010912_T2_registered.nii.gz...
# 10010912_T2_stripped.nii.gz already exists
# # 3 Applying skull mask to 10010912_WB_registered.nii.gz...
# 10010912_WB_stripped.nii.gz already exists
# # 4 Applying skull mask to 10027303_3D_FLAIR_registered.nii.gz...
# 10027303_3D_FLAIR_stripped.nii.gz already exists
# # 4 Applying skull mask to 10027303_BB_registered.nii.gz...
# 10027303_BB_stripped.nii.gz already exists
# # 4 Applying skull mask to 10027303_FLAIR_registered.nii.gz...
# 10027303_FLAIR_stripped.nii.gz already exists
# # 4 Applying skull mask to 10027303_T1_registered.nii.gz...
# 10027303_T1_stripped.nii.gz already exists
# # 4 Applying skull mask to 10027303_T2_registered.nii.gz...
# 10027303_T2_stripped.nii.gz already exists
# # 4 Applying skull mask to 10027303_WB_registered.nii.gz...
# 10027303_WB_stripped.nii.gz already exists
# # 5 Applying skull mask to 10037982_3D_FLAIR_registered.nii.gz...
# 10037982_3D_FLAIR_stripped.nii.gz already exists
# # 5 Applying skull mask to 10037982_BB_registered.nii.gz...
# 10037982_BB_stripped.nii.gz already exists
# # 5 Applying skull mask to 10037982_FLAIR_registered.nii.gz...
# 10037982_FLAIR_stripped.nii.gz already exists
# # 5 Applying skull mask to 10037982_T1_registered.nii.gz...
# 10037982_T1_stripped.nii.gz already exists
# # 5 Applying skull mask to 10037982_T2_registered.nii.gz...
# 10037982_T2_stripped.nii.gz already exists
# # 5 Applying skull mask to 10037982_WB_registered.nii.gz...
# 10037982_WB_stripped.nii.gz already exists
# # 6 Applying skull mask to 10054223_3D_FLAIR_registered.nii.gz...
# 10054223_3D_FLAIR_stripped.nii.gz already exists
# # 6 Applying skull mask to 10054223_BB_registered.nii.gz...
# 10054223_BB_stripped.nii.gz already exists
# # 6 Applying skull mask to 10054223_FLAIR_registered.nii.gz...
# 10054223_FLAIR_stripped.nii.gz already exists
# # 6 Applying skull mask to 10054223_T1_registered.nii.gz...
# 10054223_T1_stripped.nii.gz already exists
# # 6 Applying skull mask to 10054223_T2_registered.nii.gz...
# 10054223_T2_stripped.nii.gz already exists
# # 6 Applying skull mask to 10054223_WB_registered.nii.gz...
# 10054223_WB_stripped.nii.gz already exists
# # 7 Applying skull mask to 10056555_3D_FLAIR_registered.nii.gz...
# 10056555_3D_FLAIR_stripped.nii.gz already exists
# # 7 Applying skull mask to 10056555_BB_registered.nii.gz...
# 10056555_BB_stripped.nii.gz already exists
# # 7 Applying skull mask to 10056555_FLAIR_registered.nii.gz...
# 10056555_FLAIR_stripped.nii.gz already exists
# # 7 Applying skull mask to 10056555_T1_registered.nii.gz...
# 10056555_T1_stripped.nii.gz already exists
# # 7 Applying skull mask to 10056555_T2_registered.nii.gz...
# 10056555_T2_stripped.nii.gz already exists
# # 7 Applying skull mask to 10056555_WB_registered.nii.gz...
# 10056555_WB_stripped.nii.gz already exists
# # 8 Applying skull mask to 10057650_3D_FLAIR_registered.nii.gz...
# 10057650_3D_FLAIR_stripped.nii.gz already exists
# # 8 Applying skull mask to 10057650_BB_registered.nii.gz...
# 10057650_BB_stripped.nii.gz already exists
# # 8 Applying skull mask to 10057650_FLAIR_registered.nii.gz...
# 10057650_FLAIR_stripped.nii.gz already exists
# # 8 Applying skull mask to 10057650_T1_registered.nii.gz...
# 10057650_T1_stripped.nii.gz already exists
# # 8 Applying skull mask to 10057650_T2_registered.nii.gz...
# 10057650_T2_stripped.nii.gz already exists
# # 8 Applying skull mask to 10057650_WB_registered.nii.gz...
# 10057650_WB_stripped.nii.gz already exists
# # 9 Applying skull mask to 10058242_3D_FLAIR_registered.nii.gz...
# 10058242_3D_FLAIR_stripped.nii.gz already exists
# # 9 Applying skull mask to 10058242_BB_registered.nii.gz...
# 10058242_BB_stripped.nii.gz already exists
# # 9 Applying skull mask to 10058242_FLAIR_registered.nii.gz...
# 10058242_FLAIR_stripped.nii.gz already exists
# # 9 Applying skull mask to 10058242_T1_registered.nii.gz...
# 10058242_T1_stripped.nii.gz already exists
# # 9 Applying skull mask to 10058242_T2_registered.nii.gz...
# 10058242_T2_stripped.nii.gz already exists
# # 9 Applying skull mask to 10058242_WB_registered.nii.gz...
# 10058242_WB_stripped.nii.gz already exists
# # 10 Applying skull mask to 10068548_3D_FLAIR_registered.nii.gz...
# 10068548_3D_FLAIR_stripped.nii.gz already exists
# # 10 Applying skull mask to 10068548_BB_registered.nii.gz...
# 10068548_BB_stripped.nii.gz already exists
# # 10 Applying skull mask to 10068548_FLAIR_registered.nii.gz...
# 10068548_FLAIR_stripped.nii.gz already exists
# # 10 Applying skull mask to 10068548_T1_registered.nii.gz...
# 10068548_T1_stripped.nii.gz already exists
# # 10 Applying skull mask to 10068548_T2_registered.nii.gz...
# 10068548_T2_stripped.nii.gz already exists
# # 10 Applying skull mask to 10068548_WB_registered.nii.gz...
# 10068548_WB_stripped.nii.gz already exists
# # 11 Applying skull mask to 10069603_3D_FLAIR_registered.nii.gz...
# 10069603_3D_FLAIR_stripped.nii.gz already exists
# # 11 Applying skull mask to 10069603_BB_registered.nii.gz...
# 10069603_BB_stripped.nii.gz already exists
# # 11 Applying skull mask to 10069603_FLAIR_registered.nii.gz...
# 10069603_FLAIR_stripped.nii.gz already exists
# # 11 Applying skull mask to 10069603_T1_registered.nii.gz...
# 10069603_T1_stripped.nii.gz already exists
# # 11 Applying skull mask to 10069603_T2_registered.nii.gz...
# 10069603_T2_stripped.nii.gz already exists
# # 11 Applying skull mask to 10069603_WB_registered.nii.gz...
# 10069603_WB_stripped.nii.gz already exists
# # 12 Applying skull mask to 10070148_3D_FLAIR_registered.nii.gz...
# 10070148_3D_FLAIR_stripped.nii.gz already exists
# # 12 Applying skull mask to 10070148_BB_registered.nii.gz...
# 10070148_BB_stripped.nii.gz already exists
# # 12 Applying skull mask to 10070148_FLAIR_registered.nii.gz...
# 10070148_FLAIR_stripped.nii.gz already exists
# # 12 Applying skull mask to 10070148_T1_registered.nii.gz...
# 10070148_T1_stripped.nii.gz already exists
# # 12 Applying skull mask to 10070148_T2_registered.nii.gz...
# 10070148_T2_stripped.nii.gz already exists
# # 12 Applying skull mask to 10070148_WB_registered.nii.gz...
# 10070148_WB_stripped.nii.gz already exists
# # 13 Applying skull mask to 10072105_3D_FLAIR_registered.nii.gz...
# 10072105_3D_FLAIR_stripped.nii.gz already exists
# # 13 Applying skull mask to 10072105_BB_registered.nii.gz...
# 10072105_BB_stripped.nii.gz already exists
# # 13 Applying skull mask to 10072105_FLAIR_registered.nii.gz...
# 10072105_FLAIR_stripped.nii.gz already exists
# # 13 Applying skull mask to 10072105_T1_registered.nii.gz...
# 10072105_T1_stripped.nii.gz already exists
# # 13 Applying skull mask to 10072105_T2_registered.nii.gz...
# 10072105_T2_stripped.nii.gz already exists
# # 13 Applying skull mask to 10072105_WB_registered.nii.gz...
# 10072105_WB_stripped.nii.gz already exists
# # 14 Applying skull mask to 10073290_3D_FLAIR_registered.nii.gz...
# 10073290_3D_FLAIR_stripped.nii.gz already exists
# # 14 Applying skull mask to 10073290_BB_registered.nii.gz...
# 10073290_BB_stripped.nii.gz already exists
# # 14 Applying skull mask to 10073290_FLAIR_registered.nii.gz...
# 10073290_FLAIR_stripped.nii.gz already exists
# # 14 Applying skull mask to 10073290_T1_registered.nii.gz...
# 10073290_T1_stripped.nii.gz already exists
# # 14 Applying skull mask to 10073290_T2_registered.nii.gz...
# 10073290_T2_stripped.nii.gz already exists
# # 14 Applying skull mask to 10073290_WB_registered.nii.gz...
# 10073290_WB_stripped.nii.gz already exists
# # 15 Applying skull mask to 10087681_3D_FLAIR_registered.nii.gz...
# 10087681_3D_FLAIR_stripped.nii.gz already exists
# # 15 Applying skull mask to 10087681_BB_registered.nii.gz...
# 10087681_BB_stripped.nii.gz already exists
# # 15 Applying skull mask to 10087681_FLAIR_registered.nii.gz...
# 10087681_FLAIR_stripped.nii.gz already exists
# # 15 Applying skull mask to 10087681_T1_registered.nii.gz...
# 10087681_T1_stripped.nii.gz already exists
# # 15 Applying skull mask to 10087681_T2_registered.nii.gz...
# 10087681_T2_stripped.nii.gz already exists
# # 15 Applying skull mask to 10087681_WB_registered.nii.gz...
# 10087681_WB_stripped.nii.gz already exists
# # 16 Applying skull mask to 10088351_3D_FLAIR_registered.nii.gz...
# 10088351_3D_FLAIR_stripped.nii.gz already exists
# # 16 Applying skull mask to 10088351_BB_registered.nii.gz...
# 10088351_BB_stripped.nii.gz already exists
# # 16 Applying skull mask to 10088351_FLAIR_registered.nii.gz...
# 10088351_FLAIR_stripped.nii.gz already exists
# # 16 Applying skull mask to 10088351_T1_registered.nii.gz...
# 10088351_T1_stripped.nii.gz already exists
# # 16 Applying skull mask to 10088351_T2_registered.nii.gz...
# 10088351_T2_stripped.nii.gz already exists
# # 16 Applying skull mask to 10088351_WB_registered.nii.gz...
# 10088351_WB_stripped.nii.gz already exists
# # 17 Applying skull mask to 10097640_3D_FLAIR_registered.nii.gz...
# 10097640_3D_FLAIR_stripped.nii.gz already exists
# # 17 Applying skull mask to 10097640_BB_registered.nii.gz...
# 10097640_BB_stripped.nii.gz already exists
# # 17 Applying skull mask to 10097640_FLAIR_registered.nii.gz...
# 10097640_FLAIR_stripped.nii.gz already exists
# # 17 Applying skull mask to 10097640_T1_registered.nii.gz...
# 10097640_T1_stripped.nii.gz already exists
# # 17 Applying skull mask to 10097640_T2_registered.nii.gz...
# 10097640_T2_stripped.nii.gz already exists
# # 17 Applying skull mask to 10097640_WB_registered.nii.gz...
# 10097640_WB_stripped.nii.gz already exists
# # 18 Applying skull mask to 10099110_3D_FLAIR_registered.nii.gz...
# 10099110_3D_FLAIR_stripped.nii.gz already exists
# # 18 Applying skull mask to 10099110_BB_registered.nii.gz...
# 10099110_BB_stripped.nii.gz already exists
# # 18 Applying skull mask to 10099110_FLAIR_registered.nii.gz...
# 10099110_FLAIR_stripped.nii.gz already exists
# # 18 Applying skull mask to 10099110_T1_registered.nii.gz...
# 10099110_T1_stripped.nii.gz already exists
# # 18 Applying skull mask to 10099110_T2_registered.nii.gz...
# 10099110_T2_stripped.nii.gz already exists
# # 18 Applying skull mask to 10099110_WB_registered.nii.gz...
# 10099110_WB_stripped.nii.gz already exists
# # 19 Applying skull mask to 10100109_3D_FLAIR_registered.nii.gz...
# 10100109_3D_FLAIR_stripped.nii.gz already exists
# # 19 Applying skull mask to 10100109_BB_registered.nii.gz...
# 10100109_BB_stripped.nii.gz already exists
# # 19 Applying skull mask to 10100109_FLAIR_registered.nii.gz...
# 10100109_FLAIR_stripped.nii.gz already exists
# # 19 Applying skull mask to 10100109_T1_registered.nii.gz...
# 10100109_T1_stripped.nii.gz already exists
# # 19 Applying skull mask to 10100109_T2_registered.nii.gz...
# 10100109_T2_stripped.nii.gz already exists
# # 19 Applying skull mask to 10100109_WB_registered.nii.gz...
# 10100109_WB_stripped.nii.gz already exists
# # 20 Applying skull mask to 10103030_3D_FLAIR_registered.nii.gz...
# 10103030_3D_FLAIR_stripped.nii.gz already exists
# # 20 Applying skull mask to 10103030_BB_registered.nii.gz...
# 10103030_BB_stripped.nii.gz already exists
# # 20 Applying skull mask to 10103030_FLAIR_registered.nii.gz...
# 10103030_FLAIR_stripped.nii.gz already exists
# # 20 Applying skull mask to 10103030_T1_registered.nii.gz...
# 10103030_T1_stripped.nii.gz already exists
# # 20 Applying skull mask to 10103030_T2_registered.nii.gz...
# 10103030_T2_stripped.nii.gz already exists
# # 20 Applying skull mask to 10103030_WB_registered.nii.gz...
# 10103030_WB_stripped.nii.gz already exists
# # 21 Applying skull mask to 10105640_3D_FLAIR_registered.nii.gz...
# 10105640_3D_FLAIR_stripped.nii.gz already exists
# # 21 Applying skull mask to 10105640_BB_registered.nii.gz...
# 10105640_BB_stripped.nii.gz already exists
# # 21 Applying skull mask to 10105640_FLAIR_registered.nii.gz...
# 10105640_FLAIR_stripped.nii.gz already exists
# # 21 Applying skull mask to 10105640_T1_registered.nii.gz...
# 10105640_T1_stripped.nii.gz already exists
# # 21 Applying skull mask to 10105640_T2_registered.nii.gz...
# 10105640_T2_stripped.nii.gz already exists
# # 21 Applying skull mask to 10105640_WB_registered.nii.gz...
# 10105640_WB_stripped.nii.gz already exists
# # 22 Applying skull mask to 10118423_3D_FLAIR_registered.nii.gz...
# 10118423_3D_FLAIR_stripped.nii.gz already exists
# # 22 Applying skull mask to 10118423_BB_registered.nii.gz...
# 10118423_BB_stripped.nii.gz already exists
# # 22 Applying skull mask to 10118423_FLAIR_registered.nii.gz...
# 10118423_FLAIR_stripped.nii.gz already exists
# # 22 Applying skull mask to 10118423_T1_registered.nii.gz...
# 10118423_T1_stripped.nii.gz already exists
# # 22 Applying skull mask to 10118423_T2_registered.nii.gz...
# 10118423_T2_stripped.nii.gz already exists
# # 22 Applying skull mask to 10118423_WB_registered.nii.gz...
# 10118423_WB_stripped.nii.gz already exists
# # 23 Applying skull mask to 10136010_3D_FLAIR_registered.nii.gz...
# 10136010_3D_FLAIR_stripped.nii.gz already exists
# # 23 Applying skull mask to 10136010_BB_registered.nii.gz...
# 10136010_BB_stripped.nii.gz already exists
# # 23 Applying skull mask to 10136010_FLAIR_registered.nii.gz...
# 10136010_FLAIR_stripped.nii.gz already exists
# # 23 Applying skull mask to 10136010_T1_registered.nii.gz...
# 10136010_T1_stripped.nii.gz already exists
# # 23 Applying skull mask to 10136010_T2_registered.nii.gz...
# 10136010_T2_stripped.nii.gz already exists
# # 23 Applying skull mask to 10136010_WB_registered.nii.gz...
# 10136010_WB_stripped.nii.gz already exists
# # 24 Applying skull mask to 10139148_3D_FLAIR_registered.nii.gz...
# 10139148_3D_FLAIR_stripped.nii.gz already exists
# # 24 Applying skull mask to 10139148_BB_registered.nii.gz...
# 10139148_BB_stripped.nii.gz already exists
# # 24 Applying skull mask to 10139148_FLAIR_registered.nii.gz...
# 10139148_FLAIR_stripped.nii.gz already exists
# # 24 Applying skull mask to 10139148_T1_registered.nii.gz...
# 10139148_T1_stripped.nii.gz already exists
# # 24 Applying skull mask to 10139148_T2_registered.nii.gz...
# 10139148_T2_stripped.nii.gz already exists
# # 24 Applying skull mask to 10139148_WB_registered.nii.gz...
# 10139148_WB_stripped.nii.gz already exists
# # 25 Applying skull mask to 10139760_3D_FLAIR_registered.nii.gz...
# 10139760_3D_FLAIR_stripped.nii.gz already exists
# # 25 Applying skull mask to 10139760_BB_registered.nii.gz...
# 10139760_BB_stripped.nii.gz already exists
# # 25 Applying skull mask to 10139760_FLAIR_registered.nii.gz...
# 10139760_FLAIR_stripped.nii.gz already exists
# # 25 Applying skull mask to 10139760_T1_registered.nii.gz...
# 10139760_T1_stripped.nii.gz already exists
# # 25 Applying skull mask to 10139760_T2_registered.nii.gz...
# 10139760_T2_stripped.nii.gz already exists
# # 25 Applying skull mask to 10139760_WB_registered.nii.gz...
# 10139760_WB_stripped.nii.gz already exists
# # 26 Applying skull mask to 10140324_3D_FLAIR_registered.nii.gz...
# 10140324_3D_FLAIR_stripped.nii.gz already exists
# # 26 Applying skull mask to 10140324_BB_registered.nii.gz...
# 10140324_BB_stripped.nii.gz already exists
# # 26 Applying skull mask to 10140324_FLAIR_registered.nii.gz...
# 10140324_FLAIR_stripped.nii.gz already exists
# # 26 Applying skull mask to 10140324_T1_registered.nii.gz...
# 10140324_T1_stripped.nii.gz already exists
# # 26 Applying skull mask to 10140324_T2_registered.nii.gz...
# 10140324_T2_stripped.nii.gz already exists
# # 26 Applying skull mask to 10140324_WB_registered.nii.gz...
# 10140324_WB_stripped.nii.gz already exists
# # 27 Applying skull mask to 10140649_3D_FLAIR_registered.nii.gz...
# 10140649_3D_FLAIR_stripped.nii.gz already exists
# # 27 Applying skull mask to 10140649_BB_registered.nii.gz...
# 10140649_BB_stripped.nii.gz already exists
# # 27 Applying skull mask to 10140649_FLAIR_registered.nii.gz...
# 10140649_FLAIR_stripped.nii.gz already exists
# # 27 Applying skull mask to 10140649_T1_registered.nii.gz...
# 10140649_T1_stripped.nii.gz already exists
# # 27 Applying skull mask to 10140649_T2_registered.nii.gz...
# 10140649_T2_stripped.nii.gz already exists
# # 27 Applying skull mask to 10140649_WB_registered.nii.gz...
# 10140649_WB_stripped.nii.gz already exists
# # 28 Applying skull mask to 10141041_3D_FLAIR_registered.nii.gz...
# 10141041_3D_FLAIR_stripped.nii.gz already exists
# # 28 Applying skull mask to 10141041_BB_registered.nii.gz...
# 10141041_BB_stripped.nii.gz already exists
# # 28 Applying skull mask to 10141041_FLAIR_registered.nii.gz...
# 10141041_FLAIR_stripped.nii.gz already exists
# # 28 Applying skull mask to 10141041_T1_registered.nii.gz...
# 10141041_T1_stripped.nii.gz already exists
# # 28 Applying skull mask to 10141041_T2_registered.nii.gz...
# 10141041_T2_stripped.nii.gz already exists
# # 28 Applying skull mask to 10141041_WB_registered.nii.gz...
# 10141041_WB_stripped.nii.gz already exists
# # 29 Applying skull mask to 10148609_3D_FLAIR_registered.nii.gz...
# 10148609_3D_FLAIR_stripped.nii.gz already exists
# # 29 Applying skull mask to 10148609_BB_registered.nii.gz...
# 10148609_BB_stripped.nii.gz already exists
# # 29 Applying skull mask to 10148609_FLAIR_registered.nii.gz...
# 10148609_FLAIR_stripped.nii.gz already exists
# # 29 Applying skull mask to 10148609_T1_registered.nii.gz...
# 10148609_T1_stripped.nii.gz already exists
# # 29 Applying skull mask to 10148609_T2_registered.nii.gz...
# 10148609_T2_stripped.nii.gz already exists
# # 29 Applying skull mask to 10148609_WB_registered.nii.gz...
# 10148609_WB_stripped.nii.gz already exists
# # 30 Applying skull mask to 10148978_3D_FLAIR_registered.nii.gz...
# 10148978_3D_FLAIR_stripped.nii.gz already exists
# # 30 Applying skull mask to 10148978_BB_registered.nii.gz...
# 10148978_BB_stripped.nii.gz already exists
# # 30 Applying skull mask to 10148978_FLAIR_registered.nii.gz...
# 10148978_FLAIR_stripped.nii.gz already exists
# # 30 Applying skull mask to 10148978_T1_registered.nii.gz...
# 10148978_T1_stripped.nii.gz already exists
# # 30 Applying skull mask to 10148978_T2_registered.nii.gz...
# 10148978_T2_stripped.nii.gz already exists
# # 30 Applying skull mask to 10148978_WB_registered.nii.gz...
# 10148978_WB_stripped.nii.gz already exists
# # 31 Applying skull mask to 10151378_3D_FLAIR_registered.nii.gz...
# 10151378_3D_FLAIR_stripped.nii.gz already exists
# # 31 Applying skull mask to 10151378_BB_registered.nii.gz...
# 10151378_BB_stripped.nii.gz already exists
# # 31 Applying skull mask to 10151378_FLAIR_registered.nii.gz...
# 10151378_FLAIR_stripped.nii.gz already exists
# # 31 Applying skull mask to 10151378_T1_registered.nii.gz...
# 10151378_T1_stripped.nii.gz already exists
# # 31 Applying skull mask to 10151378_T2_registered.nii.gz...
# 10151378_T2_stripped.nii.gz already exists
# # 31 Applying skull mask to 10151378_WB_registered.nii.gz...
# 10151378_WB_stripped.nii.gz already exists
# # 32 Applying skull mask to 10157278_3D_FLAIR_registered.nii.gz...
# 10157278_3D_FLAIR_stripped.nii.gz already exists
# # 32 Applying skull mask to 10157278_BB_registered.nii.gz...
# 10157278_BB_stripped.nii.gz already exists
# # 32 Applying skull mask to 10157278_FLAIR_registered.nii.gz...
# 10157278_FLAIR_stripped.nii.gz already exists
# # 32 Applying skull mask to 10157278_T1_registered.nii.gz...
# 10157278_T1_stripped.nii.gz already exists
# # 32 Applying skull mask to 10157278_T2_registered.nii.gz...
# 10157278_T2_stripped.nii.gz already exists
# # 32 Applying skull mask to 10157278_WB_registered.nii.gz...
# 10157278_WB_stripped.nii.gz already exists
# # 33 Applying skull mask to 10175980_3D_FLAIR_registered.nii.gz...
# 10175980_3D_FLAIR_stripped.nii.gz already exists
# # 33 Applying skull mask to 10175980_BB_registered.nii.gz...
# 10175980_BB_stripped.nii.gz already exists
# # 33 Applying skull mask to 10175980_FLAIR_registered.nii.gz...
# 10175980_FLAIR_stripped.nii.gz already exists
# # 33 Applying skull mask to 10175980_T1_registered.nii.gz...
# 10175980_T1_stripped.nii.gz already exists
# # 33 Applying skull mask to 10175980_T2_registered.nii.gz...
# 10175980_T2_stripped.nii.gz already exists
# # 33 Applying skull mask to 10175980_WB_registered.nii.gz...
# 10175980_WB_stripped.nii.gz already exists
# # 34 Applying skull mask to 10177293_3D_FLAIR_registered.nii.gz...
# 10177293_3D_FLAIR_stripped.nii.gz already exists
# # 34 Applying skull mask to 10177293_BB_registered.nii.gz...
# 10177293_BB_stripped.nii.gz already exists
# # 34 Applying skull mask to 10177293_FLAIR_registered.nii.gz...
# 10177293_FLAIR_stripped.nii.gz already exists
# # 34 Applying skull mask to 10177293_T1_registered.nii.gz...
# 10177293_T1_stripped.nii.gz already exists
# # 34 Applying skull mask to 10177293_T2_registered.nii.gz...
# 10177293_T2_stripped.nii.gz already exists
# # 34 Applying skull mask to 10177293_WB_registered.nii.gz...
# 10177293_WB_stripped.nii.gz already exists
# # 35 Applying skull mask to 10180370_3D_FLAIR_registered.nii.gz...
# 10180370_3D_FLAIR_stripped.nii.gz already exists
# # 35 Applying skull mask to 10180370_BB_registered.nii.gz...
# 10180370_BB_stripped.nii.gz already exists
# # 35 Applying skull mask to 10180370_FLAIR_registered.nii.gz...
# 10180370_FLAIR_stripped.nii.gz already exists
# # 35 Applying skull mask to 10180370_T1_registered.nii.gz...
# 10180370_T1_stripped.nii.gz already exists
# # 35 Applying skull mask to 10180370_T2_registered.nii.gz...
# 10180370_T2_stripped.nii.gz already exists
# # 35 Applying skull mask to 10180370_WB_registered.nii.gz...
# 10180370_WB_stripped.nii.gz already exists
# # 36 Applying skull mask to 10180814_3D_FLAIR_registered.nii.gz...
# 10180814_3D_FLAIR_stripped.nii.gz already exists
# # 36 Applying skull mask to 10180814_BB_registered.nii.gz...
# 10180814_BB_stripped.nii.gz already exists
# # 36 Applying skull mask to 10180814_FLAIR_registered.nii.gz...
# 10180814_FLAIR_stripped.nii.gz already exists
# # 36 Applying skull mask to 10180814_T1_registered.nii.gz...
# 10180814_T1_stripped.nii.gz already exists
# # 36 Applying skull mask to 10180814_T2_registered.nii.gz...
# 10180814_T2_stripped.nii.gz already exists
# # 36 Applying skull mask to 10180814_WB_registered.nii.gz...
# 10180814_WB_stripped.nii.gz already exists
# # 37 Applying skull mask to 10182231_3D_FLAIR_registered.nii.gz...
# 10182231_3D_FLAIR_stripped.nii.gz already exists
# # 37 Applying skull mask to 10182231_BB_registered.nii.gz...
# 10182231_BB_stripped.nii.gz already exists
# # 37 Applying skull mask to 10182231_FLAIR_registered.nii.gz...
# 10182231_FLAIR_stripped.nii.gz already exists
# # 37 Applying skull mask to 10182231_T1_registered.nii.gz...
# 10182231_T1_stripped.nii.gz already exists
# # 37 Applying skull mask to 10182231_T2_registered.nii.gz...
# 10182231_T2_stripped.nii.gz already exists
# # 37 Applying skull mask to 10182231_WB_registered.nii.gz...
# 10182231_WB_stripped.nii.gz already exists
# # 38 Applying skull mask to 10182250_3D_FLAIR_registered.nii.gz...
# 10182250_3D_FLAIR_stripped.nii.gz already exists
# # 38 Applying skull mask to 10182250_BB_registered.nii.gz...
# 10182250_BB_stripped.nii.gz already exists
# # 38 Applying skull mask to 10182250_FLAIR_registered.nii.gz...
# 10182250_FLAIR_stripped.nii.gz already exists
# # 38 Applying skull mask to 10182250_T1_registered.nii.gz...
# 10182250_T1_stripped.nii.gz already exists
# # 38 Applying skull mask to 10182250_T2_registered.nii.gz...
# 10182250_T2_stripped.nii.gz already exists
# # 38 Applying skull mask to 10182250_WB_registered.nii.gz...
# 10182250_WB_stripped.nii.gz already exists
# # 39 Applying skull mask to 10183854_3D_FLAIR_registered.nii.gz...
# 10183854_3D_FLAIR_stripped.nii.gz already exists
# # 39 Applying skull mask to 10183854_BB_registered.nii.gz...
# 10183854_BB_stripped.nii.gz already exists
# # 39 Applying skull mask to 10183854_FLAIR_registered.nii.gz...
# 10183854_FLAIR_stripped.nii.gz already exists
# # 39 Applying skull mask to 10183854_T1_registered.nii.gz...
# 10183854_T1_stripped.nii.gz already exists
# # 39 Applying skull mask to 10183854_T2_registered.nii.gz...
# 10183854_T2_stripped.nii.gz already exists
# # 39 Applying skull mask to 10183854_WB_registered.nii.gz...
# 10183854_WB_stripped.nii.gz already exists
# # 40 Applying skull mask to 10186418_3D_FLAIR_registered.nii.gz...
# 10186418_3D_FLAIR_stripped.nii.gz already exists
# # 40 Applying skull mask to 10186418_BB_registered.nii.gz...
# 10186418_BB_stripped.nii.gz already exists
# # 40 Applying skull mask to 10186418_FLAIR_registered.nii.gz...
# 10186418_FLAIR_stripped.nii.gz already exists
# # 40 Applying skull mask to 10186418_T1_registered.nii.gz...
# 10186418_T1_stripped.nii.gz already exists
# # 40 Applying skull mask to 10186418_T2_registered.nii.gz...
# 10186418_T2_stripped.nii.gz already exists
# # 40 Applying skull mask to 10186418_WB_registered.nii.gz...
# 10186418_WB_stripped.nii.gz already exists
# # 41 Applying skull mask to 10194815_3D_FLAIR_registered.nii.gz...
# 10194815_3D_FLAIR_stripped.nii.gz already exists
# # 41 Applying skull mask to 10194815_BB_registered.nii.gz...
# 10194815_BB_stripped.nii.gz already exists
# # 41 Applying skull mask to 10194815_FLAIR_registered.nii.gz...
# 10194815_FLAIR_stripped.nii.gz already exists
# # 41 Applying skull mask to 10194815_T1_registered.nii.gz...
# 10194815_T1_stripped.nii.gz already exists
# # 41 Applying skull mask to 10194815_T2_registered.nii.gz...
# 10194815_T2_stripped.nii.gz already exists
# # 41 Applying skull mask to 10194815_WB_registered.nii.gz...
# 10194815_WB_stripped.nii.gz already exists
# # 42 Applying skull mask to 10199561_3D_FLAIR_registered.nii.gz...
# 10199561_3D_FLAIR_stripped.nii.gz already exists
# # 42 Applying skull mask to 10199561_BB_registered.nii.gz...
# 10199561_BB_stripped.nii.gz already exists
# # 42 Applying skull mask to 10199561_FLAIR_registered.nii.gz...
# 10199561_FLAIR_stripped.nii.gz already exists
# # 42 Applying skull mask to 10199561_T1_registered.nii.gz...
# 10199561_T1_stripped.nii.gz already exists
# # 42 Applying skull mask to 10199561_T2_registered.nii.gz...
# 10199561_T2_stripped.nii.gz already exists
# # 42 Applying skull mask to 10199561_WB_registered.nii.gz...
# 10199561_WB_stripped.nii.gz already exists
# # 43 Applying skull mask to 10199720_3D_FLAIR_registered.nii.gz...
# 10199720_3D_FLAIR_stripped.nii.gz already exists
# # 43 Applying skull mask to 10199720_BB_registered.nii.gz...
# 10199720_BB_stripped.nii.gz already exists
# # 43 Applying skull mask to 10199720_FLAIR_registered.nii.gz...
# 10199720_FLAIR_stripped.nii.gz already exists
# # 43 Applying skull mask to 10199720_T1_registered.nii.gz...
# 10199720_T1_stripped.nii.gz already exists
# # 43 Applying skull mask to 10199720_T2_registered.nii.gz...
# 10199720_T2_stripped.nii.gz already exists
# # 43 Applying skull mask to 10199720_WB_registered.nii.gz...
# 10199720_WB_stripped.nii.gz already exists
# # 44 Applying skull mask to 10201823_3D_FLAIR_registered.nii.gz...
# 10201823_3D_FLAIR_stripped.nii.gz already exists
# # 44 Applying skull mask to 10201823_BB_registered.nii.gz...
# 10201823_BB_stripped.nii.gz already exists
# # 44 Applying skull mask to 10201823_FLAIR_registered.nii.gz...
# 10201823_FLAIR_stripped.nii.gz already exists
# # 44 Applying skull mask to 10201823_T1_registered.nii.gz...
# 10201823_T1_stripped.nii.gz already exists
# # 44 Applying skull mask to 10201823_T2_registered.nii.gz...
# 10201823_T2_stripped.nii.gz already exists
# # 44 Applying skull mask to 10201823_WB_registered.nii.gz...
# 10201823_WB_stripped.nii.gz already exists
# # 45 Applying skull mask to 10205347_3D_FLAIR_registered.nii.gz...
# 10205347_3D_FLAIR_stripped.nii.gz already exists
# # 45 Applying skull mask to 10205347_BB_registered.nii.gz...
# 10205347_BB_stripped.nii.gz already exists
# # 45 Applying skull mask to 10205347_FLAIR_registered.nii.gz...
# 10205347_FLAIR_stripped.nii.gz already exists
# # 45 Applying skull mask to 10205347_T1_registered.nii.gz...
# 10205347_T1_stripped.nii.gz already exists
# # 45 Applying skull mask to 10205347_T2_registered.nii.gz...
# 10205347_T2_stripped.nii.gz already exists
# # 45 Applying skull mask to 10205347_WB_registered.nii.gz...
# 10205347_WB_stripped.nii.gz already exists
# # 46 Applying skull mask to 10205378_3D_FLAIR_registered.nii.gz...
# 10205378_3D_FLAIR_stripped.nii.gz already exists
# # 46 Applying skull mask to 10205378_BB_registered.nii.gz...
# 10205378_BB_stripped.nii.gz already exists
# # 46 Applying skull mask to 10205378_FLAIR_registered.nii.gz...
# 10205378_FLAIR_stripped.nii.gz already exists
# # 46 Applying skull mask to 10205378_T1_registered.nii.gz...
# 10205378_T1_stripped.nii.gz already exists
# # 46 Applying skull mask to 10205378_T2_registered.nii.gz...
# 10205378_T2_stripped.nii.gz already exists
# # 46 Applying skull mask to 10205378_WB_registered.nii.gz...
# 10205378_WB_stripped.nii.gz already exists
# # 47 Applying skull mask to 10205872_3D_FLAIR_registered.nii.gz...
# 10205872_3D_FLAIR_stripped.nii.gz already exists
# # 47 Applying skull mask to 10205872_BB_registered.nii.gz...
# 10205872_BB_stripped.nii.gz already exists
# # 47 Applying skull mask to 10205872_FLAIR_registered.nii.gz...
# 10205872_FLAIR_stripped.nii.gz already exists
# # 47 Applying skull mask to 10205872_T1_registered.nii.gz...
# 10205872_T1_stripped.nii.gz already exists
# # 47 Applying skull mask to 10205872_T2_registered.nii.gz...
# 10205872_T2_stripped.nii.gz already exists
# # 47 Applying skull mask to 10205872_WB_registered.nii.gz...
# 10205872_WB_stripped.nii.gz already exists
# # 48 Applying skull mask to 10206345_3D_FLAIR_registered.nii.gz...
# 10206345_3D_FLAIR_stripped.nii.gz already exists
# # 48 Applying skull mask to 10206345_BB_registered.nii.gz...
# 10206345_BB_stripped.nii.gz already exists
# # 48 Applying skull mask to 10206345_FLAIR_registered.nii.gz...
# 10206345_FLAIR_stripped.nii.gz already exists
# # 48 Applying skull mask to 10206345_T1_registered.nii.gz...
# 10206345_T1_stripped.nii.gz already exists
# # 48 Applying skull mask to 10206345_T2_registered.nii.gz...
# 10206345_T2_stripped.nii.gz already exists
# # 48 Applying skull mask to 10206345_WB_registered.nii.gz...
# 10206345_WB_stripped.nii.gz already exists
# # 49 Applying skull mask to 10207421_3D_FLAIR_registered.nii.gz...
# 10207421_3D_FLAIR_stripped.nii.gz already exists
# # 49 Applying skull mask to 10207421_BB_registered.nii.gz...
# 10207421_BB_stripped.nii.gz already exists
# # 49 Applying skull mask to 10207421_FLAIR_registered.nii.gz...
# 10207421_FLAIR_stripped.nii.gz already exists
# # 49 Applying skull mask to 10207421_T1_registered.nii.gz...
# 10207421_T1_stripped.nii.gz already exists
# # 49 Applying skull mask to 10207421_T2_registered.nii.gz...
# 10207421_T2_stripped.nii.gz already exists
# # 49 Applying skull mask to 10207421_WB_registered.nii.gz...
# 10207421_WB_stripped.nii.gz already exists
# # 50 Applying skull mask to 10207668_3D_FLAIR_registered.nii.gz...
# 10207668_3D_FLAIR_stripped.nii.gz already exists
# # 50 Applying skull mask to 10207668_BB_registered.nii.gz...
# 10207668_BB_stripped.nii.gz already exists
# # 50 Applying skull mask to 10207668_FLAIR_registered.nii.gz...
# 10207668_FLAIR_stripped.nii.gz already exists
# # 50 Applying skull mask to 10207668_T1_registered.nii.gz...
# 10207668_T1_stripped.nii.gz already exists
# # 50 Applying skull mask to 10207668_T2_registered.nii.gz...
# 10207668_T2_stripped.nii.gz already exists
# # 50 Applying skull mask to 10207668_WB_registered.nii.gz...
# 10207668_WB_stripped.nii.gz already exists
# # 51 Applying skull mask to 10208261_3D_FLAIR_registered.nii.gz...
# 10208261_3D_FLAIR_stripped.nii.gz already exists
# # 51 Applying skull mask to 10208261_BB_registered.nii.gz...
# 10208261_BB_stripped.nii.gz already exists
# # 51 Applying skull mask to 10208261_FLAIR_registered.nii.gz...
# 10208261_FLAIR_stripped.nii.gz already exists
# # 51 Applying skull mask to 10208261_T1_registered.nii.gz...
# 10208261_T1_stripped.nii.gz already exists
# # 51 Applying skull mask to 10208261_T2_registered.nii.gz...
# 10208261_T2_stripped.nii.gz already exists
# # 51 Applying skull mask to 10208261_WB_registered.nii.gz...
# 10208261_WB_stripped.nii.gz already exists
# # 52 Applying skull mask to 10210343_3D_FLAIR_registered.nii.gz...
# 10210343_3D_FLAIR_stripped.nii.gz already exists
# # 52 Applying skull mask to 10210343_BB_registered.nii.gz...
# 10210343_BB_stripped.nii.gz already exists
# # 52 Applying skull mask to 10210343_FLAIR_registered.nii.gz...
# 10210343_FLAIR_stripped.nii.gz already exists
# # 52 Applying skull mask to 10210343_T1_registered.nii.gz...
# 10210343_T1_stripped.nii.gz already exists
# # 52 Applying skull mask to 10210343_T2_registered.nii.gz...
# 10210343_T2_stripped.nii.gz already exists
# # 52 Applying skull mask to 10210343_WB_registered.nii.gz...
# 10210343_WB_stripped.nii.gz already exists
# # 53 Applying skull mask to 10210620_3D_FLAIR_registered.nii.gz...
# 10210620_3D_FLAIR_stripped.nii.gz already exists
# # 53 Applying skull mask to 10210620_BB_registered.nii.gz...
# 10210620_BB_stripped.nii.gz already exists
# # 53 Applying skull mask to 10210620_FLAIR_registered.nii.gz...
# 10210620_FLAIR_stripped.nii.gz already exists
# # 53 Applying skull mask to 10210620_T1_registered.nii.gz...
# 10210620_T1_stripped.nii.gz already exists
# # 53 Applying skull mask to 10210620_T2_registered.nii.gz...
# 10210620_T2_stripped.nii.gz already exists
# # 53 Applying skull mask to 10210620_WB_registered.nii.gz...
# 10210620_WB_stripped.nii.gz already exists
# # 54 Applying skull mask to 10210966_3D_FLAIR_registered.nii.gz...
# 10210966_3D_FLAIR_stripped.nii.gz already exists
# # 54 Applying skull mask to 10210966_BB_registered.nii.gz...
# 10210966_BB_stripped.nii.gz already exists
# # 54 Applying skull mask to 10210966_FLAIR_registered.nii.gz...
# 10210966_FLAIR_stripped.nii.gz already exists
# # 54 Applying skull mask to 10210966_T1_registered.nii.gz...
# 10210966_T1_stripped.nii.gz already exists
# # 54 Applying skull mask to 10210966_T2_registered.nii.gz...
# 10210966_T2_stripped.nii.gz already exists
# # 54 Applying skull mask to 10210966_WB_registered.nii.gz...
# 10210966_WB_stripped.nii.gz already exists
# # 55 Applying skull mask to 10211701_3D_FLAIR_registered.nii.gz...
# 10211701_3D_FLAIR_stripped.nii.gz already exists
# # 55 Applying skull mask to 10211701_BB_registered.nii.gz...
# 10211701_BB_stripped.nii.gz already exists
# # 55 Applying skull mask to 10211701_FLAIR_registered.nii.gz...
# 10211701_FLAIR_stripped.nii.gz already exists
# # 55 Applying skull mask to 10211701_T1_registered.nii.gz...
# 10211701_T1_stripped.nii.gz already exists
# # 55 Applying skull mask to 10211701_T2_registered.nii.gz...
# 10211701_T2_stripped.nii.gz already exists
# # 55 Applying skull mask to 10211701_WB_registered.nii.gz...
# 10211701_WB_stripped.nii.gz already exists
# # 56 Applying skull mask to 10212817_3D_FLAIR_registered.nii.gz...
# 10212817_3D_FLAIR_stripped.nii.gz already exists
# # 56 Applying skull mask to 10212817_BB_registered.nii.gz...
# 10212817_BB_stripped.nii.gz already exists
# # 56 Applying skull mask to 10212817_FLAIR_registered.nii.gz...
# 10212817_FLAIR_stripped.nii.gz already exists
# # 56 Applying skull mask to 10212817_T1_registered.nii.gz...
# 10212817_T1_stripped.nii.gz already exists
# # 56 Applying skull mask to 10212817_T2_registered.nii.gz...
# 10212817_T2_stripped.nii.gz already exists
# # 56 Applying skull mask to 10212817_WB_registered.nii.gz...
# 10212817_WB_stripped.nii.gz already exists
# # 57 Applying skull mask to 10212893_3D_FLAIR_registered.nii.gz...
# 10212893_3D_FLAIR_stripped.nii.gz already exists
# # 57 Applying skull mask to 10212893_BB_registered.nii.gz...
# 10212893_BB_stripped.nii.gz already exists
# # 57 Applying skull mask to 10212893_FLAIR_registered.nii.gz...
# 10212893_FLAIR_stripped.nii.gz already exists
# # 57 Applying skull mask to 10212893_T1_registered.nii.gz...
# 10212893_T1_stripped.nii.gz already exists
# # 57 Applying skull mask to 10212893_T2_registered.nii.gz...
# 10212893_T2_stripped.nii.gz already exists
# # 57 Applying skull mask to 10212893_WB_registered.nii.gz...
# 10212893_WB_stripped.nii.gz already exists
# # 58 Applying skull mask to 10212902_3D_FLAIR_registered.nii.gz...
# 10212902_3D_FLAIR_stripped.nii.gz already exists
# # 58 Applying skull mask to 10212902_BB_registered.nii.gz...
# 10212902_BB_stripped.nii.gz already exists
# # 58 Applying skull mask to 10212902_FLAIR_registered.nii.gz...
# 10212902_FLAIR_stripped.nii.gz already exists
# # 58 Applying skull mask to 10212902_T1_registered.nii.gz...
# 10212902_T1_stripped.nii.gz already exists
# # 58 Applying skull mask to 10212902_T2_registered.nii.gz...
# 10212902_T2_stripped.nii.gz already exists
# # 58 Applying skull mask to 10212902_WB_registered.nii.gz...
# 10212902_WB_stripped.nii.gz already exists
# # 59 Applying skull mask to 10212938_3D_FLAIR_registered.nii.gz...
# 10212938_3D_FLAIR_stripped.nii.gz already exists
# # 59 Applying skull mask to 10212938_BB_registered.nii.gz...
# 10212938_BB_stripped.nii.gz already exists
# # 59 Applying skull mask to 10212938_FLAIR_registered.nii.gz...
# 10212938_FLAIR_stripped.nii.gz already exists
# # 59 Applying skull mask to 10212938_T1_registered.nii.gz...
# 10212938_T1_stripped.nii.gz already exists
# # 59 Applying skull mask to 10212938_T2_registered.nii.gz...
# 10212938_T2_stripped.nii.gz already exists
# # 59 Applying skull mask to 10212938_WB_registered.nii.gz...
# 10212938_WB_stripped.nii.gz already exists
# # 60 Applying skull mask to 10213829_3D_FLAIR_registered.nii.gz...
# 10213829_3D_FLAIR_stripped.nii.gz already exists
# # 60 Applying skull mask to 10213829_BB_registered.nii.gz...
# 10213829_BB_stripped.nii.gz already exists
# # 60 Applying skull mask to 10213829_FLAIR_registered.nii.gz...
# 10213829_FLAIR_stripped.nii.gz already exists
# # 60 Applying skull mask to 10213829_T1_registered.nii.gz...
# 10213829_T1_stripped.nii.gz already exists
# # 60 Applying skull mask to 10213829_T2_registered.nii.gz...
# 10213829_T2_stripped.nii.gz already exists
# # 60 Applying skull mask to 10213829_WB_registered.nii.gz...
# 10213829_WB_stripped.nii.gz already exists
# # 61 Applying skull mask to 10214838_3D_FLAIR_registered.nii.gz...
# 10214838_3D_FLAIR_stripped.nii.gz already exists
# # 61 Applying skull mask to 10214838_BB_registered.nii.gz...
# 10214838_BB_stripped.nii.gz already exists
# # 61 Applying skull mask to 10214838_FLAIR_registered.nii.gz...
# 10214838_FLAIR_stripped.nii.gz already exists
# # 61 Applying skull mask to 10214838_T1_registered.nii.gz...
# 10214838_T1_stripped.nii.gz already exists
# # 61 Applying skull mask to 10214838_T2_registered.nii.gz...
# 10214838_T2_stripped.nii.gz already exists
# # 61 Applying skull mask to 10214838_WB_registered.nii.gz...
# 10214838_WB_stripped.nii.gz already exists
# # 62 Applying skull mask to 10215222_3D_FLAIR_registered.nii.gz...
# 10215222_3D_FLAIR_stripped.nii.gz already exists
# # 62 Applying skull mask to 10215222_BB_registered.nii.gz...
# 10215222_BB_stripped.nii.gz already exists
# # 62 Applying skull mask to 10215222_FLAIR_registered.nii.gz...
# 10215222_FLAIR_stripped.nii.gz already exists
# # 62 Applying skull mask to 10215222_T1_registered.nii.gz...
# 10215222_T1_stripped.nii.gz already exists
# # 62 Applying skull mask to 10215222_T2_registered.nii.gz...
# 10215222_T2_stripped.nii.gz already exists
# # 62 Applying skull mask to 10215222_WB_registered.nii.gz...
# 10215222_WB_stripped.nii.gz already exists
# # 63 Applying skull mask to 10217615_3D_FLAIR_registered.nii.gz...
# 10217615_3D_FLAIR_stripped.nii.gz already exists
# # 63 Applying skull mask to 10217615_BB_registered.nii.gz...
# 10217615_BB_stripped.nii.gz already exists
# # 63 Applying skull mask to 10217615_FLAIR_registered.nii.gz...
# 10217615_FLAIR_stripped.nii.gz already exists
# # 63 Applying skull mask to 10217615_T1_registered.nii.gz...
# 10217615_T1_stripped.nii.gz already exists
# # 63 Applying skull mask to 10217615_T2_registered.nii.gz...
# 10217615_T2_stripped.nii.gz already exists
# # 63 Applying skull mask to 10217615_WB_registered.nii.gz...
# 10217615_WB_stripped.nii.gz already exists
# # 64 Applying skull mask to 10217717_3D_FLAIR_registered.nii.gz...
# 10217717_3D_FLAIR_stripped.nii.gz already exists
# # 64 Applying skull mask to 10217717_BB_registered.nii.gz...
# 10217717_BB_stripped.nii.gz already exists
# # 64 Applying skull mask to 10217717_FLAIR_registered.nii.gz...
# 10217717_FLAIR_stripped.nii.gz already exists
# # 64 Applying skull mask to 10217717_T1_registered.nii.gz...
# 10217717_T1_stripped.nii.gz already exists
# # 64 Applying skull mask to 10217717_T2_registered.nii.gz...
# 10217717_T2_stripped.nii.gz already exists
# # 64 Applying skull mask to 10217717_WB_registered.nii.gz...
# 10217717_WB_stripped.nii.gz already exists
# # 65 Applying skull mask to 10218119_3D_FLAIR_registered.nii.gz...
# 10218119_3D_FLAIR_stripped.nii.gz already exists
# # 65 Applying skull mask to 10218119_BB_registered.nii.gz...
# 10218119_BB_stripped.nii.gz already exists
# # 65 Applying skull mask to 10218119_FLAIR_registered.nii.gz...
# 10218119_FLAIR_stripped.nii.gz already exists
# # 65 Applying skull mask to 10218119_T1_registered.nii.gz...
# 10218119_T1_stripped.nii.gz already exists
# # 65 Applying skull mask to 10218119_T2_registered.nii.gz...
# 10218119_T2_stripped.nii.gz already exists
# # 65 Applying skull mask to 10218119_WB_registered.nii.gz...
# 10218119_WB_stripped.nii.gz already exists
# # 66 Applying skull mask to 10218135_3D_FLAIR_registered.nii.gz...
# 10218135_3D_FLAIR_stripped.nii.gz already exists
# # 66 Applying skull mask to 10218135_BB_registered.nii.gz...
# 10218135_BB_stripped.nii.gz already exists
# # 66 Applying skull mask to 10218135_FLAIR_registered.nii.gz...
# 10218135_FLAIR_stripped.nii.gz already exists
# # 66 Applying skull mask to 10218135_T1_registered.nii.gz...
# 10218135_T1_stripped.nii.gz already exists
# # 66 Applying skull mask to 10218135_T2_registered.nii.gz...
# 10218135_T2_stripped.nii.gz already exists
# # 66 Applying skull mask to 10218135_WB_registered.nii.gz...
# 10218135_WB_stripped.nii.gz already exists
# # 67 Applying skull mask to 10219137_3D_FLAIR_registered.nii.gz...
# 10219137_3D_FLAIR_stripped.nii.gz already exists
# # 67 Applying skull mask to 10219137_BB_registered.nii.gz...
# 10219137_BB_stripped.nii.gz already exists
# # 67 Applying skull mask to 10219137_FLAIR_registered.nii.gz...
# 10219137_FLAIR_stripped.nii.gz already exists
# # 67 Applying skull mask to 10219137_T1_registered.nii.gz...
# 10219137_T1_stripped.nii.gz already exists
# # 67 Applying skull mask to 10219137_T2_registered.nii.gz...
# 10219137_T2_stripped.nii.gz already exists
# # 67 Applying skull mask to 10219137_WB_registered.nii.gz...
# 10219137_WB_stripped.nii.gz already exists
# # 68 Applying skull mask to 10219837_3D_FLAIR_registered.nii.gz...
# 10219837_3D_FLAIR_stripped.nii.gz already exists
# # 68 Applying skull mask to 10219837_BB_registered.nii.gz...
# 10219837_BB_stripped.nii.gz already exists
# # 68 Applying skull mask to 10219837_FLAIR_registered.nii.gz...
# 10219837_FLAIR_stripped.nii.gz already exists
# # 68 Applying skull mask to 10219837_T1_registered.nii.gz...
# 10219837_T1_stripped.nii.gz already exists
# # 68 Applying skull mask to 10219837_T2_registered.nii.gz...
# 10219837_T2_stripped.nii.gz already exists
# # 68 Applying skull mask to 10219837_WB_registered.nii.gz...
# 10219837_WB_stripped.nii.gz already exists
# # 69 Applying skull mask to 10220063_3D_FLAIR_registered.nii.gz...
# 10220063_3D_FLAIR_stripped.nii.gz already exists
# # 69 Applying skull mask to 10220063_BB_registered.nii.gz...
# 10220063_BB_stripped.nii.gz already exists
# # 69 Applying skull mask to 10220063_FLAIR_registered.nii.gz...
# 10220063_FLAIR_stripped.nii.gz already exists
# # 69 Applying skull mask to 10220063_T1_registered.nii.gz...
# 10220063_T1_stripped.nii.gz already exists
# # 69 Applying skull mask to 10220063_T2_registered.nii.gz...
# 10220063_T2_stripped.nii.gz already exists
# # 69 Applying skull mask to 10220063_WB_registered.nii.gz...
# 10220063_WB_stripped.nii.gz already exists
# # 70 Applying skull mask to 10220403_3D_FLAIR_registered.nii.gz...
# 10220403_3D_FLAIR_stripped.nii.gz already exists
# # 70 Applying skull mask to 10220403_BB_registered.nii.gz...
# 10220403_BB_stripped.nii.gz already exists
# # 70 Applying skull mask to 10220403_FLAIR_registered.nii.gz...
# 10220403_FLAIR_stripped.nii.gz already exists
# # 70 Applying skull mask to 10220403_T1_registered.nii.gz...
# 10220403_T1_stripped.nii.gz already exists
# # 70 Applying skull mask to 10220403_T2_registered.nii.gz...
# 10220403_T2_stripped.nii.gz already exists
# # 70 Applying skull mask to 10220403_WB_registered.nii.gz...
# 10220403_WB_stripped.nii.gz already exists
# # 71 Applying skull mask to 10221070_3D_FLAIR_registered.nii.gz...
# 10221070_3D_FLAIR_stripped.nii.gz already exists
# # 71 Applying skull mask to 10221070_BB_registered.nii.gz...
# 10221070_BB_stripped.nii.gz already exists
# # 71 Applying skull mask to 10221070_FLAIR_registered.nii.gz...
# 10221070_FLAIR_stripped.nii.gz already exists
# # 71 Applying skull mask to 10221070_T1_registered.nii.gz...
# 10221070_T1_stripped.nii.gz already exists
# # 71 Applying skull mask to 10221070_T2_registered.nii.gz...
# 10221070_T2_stripped.nii.gz already exists
# # 71 Applying skull mask to 10221070_WB_registered.nii.gz...
# 10221070_WB_stripped.nii.gz already exists
# # 72 Applying skull mask to 10221410_3D_FLAIR_registered.nii.gz...
# 10221410_3D_FLAIR_stripped.nii.gz already exists
# # 72 Applying skull mask to 10221410_BB_registered.nii.gz...
# 10221410_BB_stripped.nii.gz already exists
# # 72 Applying skull mask to 10221410_FLAIR_registered.nii.gz...
# 10221410_FLAIR_stripped.nii.gz already exists
# # 72 Applying skull mask to 10221410_T1_registered.nii.gz...
# 10221410_T1_stripped.nii.gz already exists
# # 72 Applying skull mask to 10221410_T2_registered.nii.gz...
# 10221410_T2_stripped.nii.gz already exists
# # 72 Applying skull mask to 10221410_WB_registered.nii.gz...
# 10221410_WB_stripped.nii.gz already exists
# # 73 Applying skull mask to 10221702_3D_FLAIR_registered.nii.gz...
# 10221702_3D_FLAIR_stripped.nii.gz already exists
# # 73 Applying skull mask to 10221702_BB_registered.nii.gz...
# 10221702_BB_stripped.nii.gz already exists
# # 73 Applying skull mask to 10221702_FLAIR_registered.nii.gz...
# 10221702_FLAIR_stripped.nii.gz already exists
# # 73 Applying skull mask to 10221702_T1_registered.nii.gz...
# 10221702_T1_stripped.nii.gz already exists
# # 73 Applying skull mask to 10221702_T2_registered.nii.gz...
# 10221702_T2_stripped.nii.gz already exists
# # 73 Applying skull mask to 10221702_WB_registered.nii.gz...
# 10221702_WB_stripped.nii.gz already exists
# # 74 Applying skull mask to 10221904_3D_FLAIR_registered.nii.gz...
# 10221904_3D_FLAIR_stripped.nii.gz already exists
# # 74 Applying skull mask to 10221904_BB_registered.nii.gz...
# 10221904_BB_stripped.nii.gz already exists
# # 74 Applying skull mask to 10221904_FLAIR_registered.nii.gz...
# 10221904_FLAIR_stripped.nii.gz already exists
# # 74 Applying skull mask to 10221904_T1_registered.nii.gz...
# 10221904_T1_stripped.nii.gz already exists
# # 74 Applying skull mask to 10221904_T2_registered.nii.gz...
# 10221904_T2_stripped.nii.gz already exists
# # 74 Applying skull mask to 10221904_WB_registered.nii.gz...
# 10221904_WB_stripped.nii.gz already exists
# # 75 Applying skull mask to 10222812_3D_FLAIR_registered.nii.gz...
# 10222812_3D_FLAIR_stripped.nii.gz already exists
# # 75 Applying skull mask to 10222812_BB_registered.nii.gz...
# 10222812_BB_stripped.nii.gz already exists
# # 75 Applying skull mask to 10222812_FLAIR_registered.nii.gz...
# 10222812_FLAIR_stripped.nii.gz already exists
# # 75 Applying skull mask to 10222812_T1_registered.nii.gz...
# 10222812_T1_stripped.nii.gz already exists
# # 75 Applying skull mask to 10222812_T2_registered.nii.gz...
# 10222812_T2_stripped.nii.gz already exists
# ...
# # 238 Applying skull mask to 8712712_WB_registered.nii.gz...
# 8712712_WB_stripped.nii.gz already exists
# # 239 Applying skull mask to 8719167_3D_FLAIR_registered.nii.gz...
# 8719167_3D_FLAIR_stripped.nii.gz already exists
# # 239 Applying skull mask to 8719167_BB_registered.nii.gz...
# 8719167_BB_stripped.nii.gz already exists
# # 239 Applying skull mask to 8719167_FLAIR_registered.nii.gz...
# 8719167_FLAIR_stripped.nii.gz already exists
# # 239 Applying skull mask to 8719167_T1_registered.nii.gz...
# 8719167_T1_stripped.nii.gz already exists
# # 239 Applying skull mask to 8719167_T2_registered.nii.gz...
# 8719167_T2_stripped.nii.gz already exists
# # 239 Applying skull mask to 8719167_WB_registered.nii.gz...
# 8719167_WB_stripped.nii.gz already exists
# # 240 Applying skull mask to 8722052_3D_FLAIR_registered.nii.gz...
# 8722052_3D_FLAIR_stripped.nii.gz already exists
# # 240 Applying skull mask to 8722052_BB_registered.nii.gz...
# 8722052_BB_stripped.nii.gz already exists
# # 240 Applying skull mask to 8722052_FLAIR_registered.nii.gz...
# 8722052_FLAIR_stripped.nii.gz already exists
# # 240 Applying skull mask to 8722052_T1_registered.nii.gz...
# 8722052_T1_stripped.nii.gz already exists
# # 240 Applying skull mask to 8722052_T2_registered.nii.gz...
# 8722052_T2_stripped.nii.gz already exists
# # 240 Applying skull mask to 8722052_WB_registered.nii.gz...
# 8722052_WB_stripped.nii.gz already exists
# # 241 Applying skull mask to 8735529_3D_FLAIR_registered.nii.gz...
# 8735529_3D_FLAIR_stripped.nii.gz already exists
# # 241 Applying skull mask to 8735529_BB_registered.nii.gz...
# 8735529_BB_stripped.nii.gz already exists
# # 241 Applying skull mask to 8735529_FLAIR_registered.nii.gz...
# 8735529_FLAIR_stripped.nii.gz already exists
# # 241 Applying skull mask to 8735529_T1_registered.nii.gz...
# 8735529_T1_stripped.nii.gz already exists
# # 241 Applying skull mask to 8735529_T2_registered.nii.gz...
# 8735529_T2_stripped.nii.gz already exists
# # 241 Applying skull mask to 8735529_WB_registered.nii.gz...
# 8735529_WB_stripped.nii.gz already exists
# # 242 Applying skull mask to 8737212_3D_FLAIR_registered.nii.gz...
# 8737212_3D_FLAIR_stripped.nii.gz already exists
# # 242 Applying skull mask to 8737212_BB_registered.nii.gz...
# 8737212_BB_stripped.nii.gz already exists
# # 242 Applying skull mask to 8737212_FLAIR_registered.nii.gz...
# 8737212_FLAIR_stripped.nii.gz already exists
# # 242 Applying skull mask to 8737212_T1_registered.nii.gz...
# 8737212_T1_stripped.nii.gz already exists
# # 242 Applying skull mask to 8737212_T2_registered.nii.gz...
# 8737212_T2_stripped.nii.gz already exists
# # 242 Applying skull mask to 8737212_WB_registered.nii.gz...
# 8737212_WB_stripped.nii.gz already exists
# # 243 Applying skull mask to 8738205_3D_FLAIR_registered.nii.gz...
# 8738205_3D_FLAIR_stripped.nii.gz already exists
# # 243 Applying skull mask to 8738205_BB_registered.nii.gz...
# 8738205_BB_stripped.nii.gz already exists
# # 243 Applying skull mask to 8738205_FLAIR_registered.nii.gz...
# 8738205_FLAIR_stripped.nii.gz already exists
# # 243 Applying skull mask to 8738205_T1_registered.nii.gz...
# 8738205_T1_stripped.nii.gz already exists
# # 243 Applying skull mask to 8738205_T2_registered.nii.gz...
# 8738205_T2_stripped.nii.gz already exists
# # 243 Applying skull mask to 8738205_WB_registered.nii.gz...
# 8738205_WB_stripped.nii.gz already exists
# # 244 Applying skull mask to 8738230_3D_FLAIR_registered.nii.gz...
# 8738230_3D_FLAIR_stripped.nii.gz already exists
# # 244 Applying skull mask to 8738230_BB_registered.nii.gz...
# 8738230_BB_stripped.nii.gz already exists
# # 244 Applying skull mask to 8738230_FLAIR_registered.nii.gz...
# 8738230_FLAIR_stripped.nii.gz already exists
# # 244 Applying skull mask to 8738230_T1_registered.nii.gz...
# 8738230_T1_stripped.nii.gz already exists
# # 244 Applying skull mask to 8738230_T2_registered.nii.gz...
# 8738230_T2_stripped.nii.gz already exists
# # 244 Applying skull mask to 8738230_WB_registered.nii.gz...
# 8738230_WB_stripped.nii.gz already exists
# # 245 Applying skull mask to 8744419_3D_FLAIR_registered.nii.gz...
# 8744419_3D_FLAIR_stripped.nii.gz already exists
# # 245 Applying skull mask to 8744419_BB_registered.nii.gz...
# 8744419_BB_stripped.nii.gz already exists
# # 245 Applying skull mask to 8744419_FLAIR_registered.nii.gz...
# 8744419_FLAIR_stripped.nii.gz already exists
# # 245 Applying skull mask to 8744419_T1_registered.nii.gz...
# 8744419_T1_stripped.nii.gz already exists
# # 245 Applying skull mask to 8744419_T2_registered.nii.gz...
# 8744419_T2_stripped.nii.gz already exists
# # 245 Applying skull mask to 8744419_WB_registered.nii.gz...
# 8744419_WB_stripped.nii.gz already exists
# # 246 Applying skull mask to 8754866_3D_FLAIR_registered.nii.gz...
# 8754866_3D_FLAIR_stripped.nii.gz already exists
# # 246 Applying skull mask to 8754866_BB_registered.nii.gz...
# 8754866_BB_stripped.nii.gz already exists
# # 246 Applying skull mask to 8754866_FLAIR_registered.nii.gz...
# 8754866_FLAIR_stripped.nii.gz already exists
# # 246 Applying skull mask to 8754866_T1_registered.nii.gz...
# 8754866_T1_stripped.nii.gz already exists
# # 246 Applying skull mask to 8754866_T2_registered.nii.gz...
# 8754866_T2_stripped.nii.gz already exists
# # 246 Applying skull mask to 8754866_WB_registered.nii.gz...
# 8754866_WB_stripped.nii.gz already exists
# # 247 Applying skull mask to 8773895_3D_FLAIR_registered.nii.gz...
# 8773895_3D_FLAIR_stripped.nii.gz already exists
# # 247 Applying skull mask to 8773895_BB_registered.nii.gz...
# 8773895_BB_stripped.nii.gz already exists
# # 247 Applying skull mask to 8773895_FLAIR_registered.nii.gz...
# 8773895_FLAIR_stripped.nii.gz already exists
# # 247 Applying skull mask to 8773895_T1_registered.nii.gz...
# 8773895_T1_stripped.nii.gz already exists
# # 247 Applying skull mask to 8773895_T2_registered.nii.gz...
# 8773895_T2_stripped.nii.gz already exists
# # 247 Applying skull mask to 8773895_WB_registered.nii.gz...
# 8773895_WB_stripped.nii.gz already exists
# # 248 Applying skull mask to 8775206_3D_FLAIR_registered.nii.gz...
# 8775206_3D_FLAIR_stripped.nii.gz already exists
# # 248 Applying skull mask to 8775206_BB_registered.nii.gz...
# 8775206_BB_stripped.nii.gz already exists
# # 248 Applying skull mask to 8775206_FLAIR_registered.nii.gz...
# 8775206_FLAIR_stripped.nii.gz already exists
# # 248 Applying skull mask to 8775206_T1_registered.nii.gz...
# 8775206_T1_stripped.nii.gz already exists
# # 248 Applying skull mask to 8775206_T2_registered.nii.gz...
# 8775206_T2_stripped.nii.gz already exists
# # 248 Applying skull mask to 8775206_WB_registered.nii.gz...
# 8775206_WB_stripped.nii.gz already exists
# # 249 Applying skull mask to 8778973_3D_FLAIR_registered.nii.gz...
# 8778973_3D_FLAIR_stripped.nii.gz already exists
# # 249 Applying skull mask to 8778973_BB_registered.nii.gz...
# 8778973_BB_stripped.nii.gz already exists
# # 249 Applying skull mask to 8778973_FLAIR_registered.nii.gz...
# 8778973_FLAIR_stripped.nii.gz already exists
# # 249 Applying skull mask to 8778973_T1_registered.nii.gz...
# 8778973_T1_stripped.nii.gz already exists
# # 249 Applying skull mask to 8778973_T2_registered.nii.gz...
# 8778973_T2_stripped.nii.gz already exists
# # 249 Applying skull mask to 8778973_WB_registered.nii.gz...
# 8778973_WB_stripped.nii.gz already exists
# # 250 Applying skull mask to 8779475_3D_FLAIR_registered.nii.gz...
# 8779475_3D_FLAIR_stripped.nii.gz already exists
# # 250 Applying skull mask to 8779475_BB_registered.nii.gz...
# 8779475_BB_stripped.nii.gz already exists
# # 250 Applying skull mask to 8779475_FLAIR_registered.nii.gz...
# 8779475_FLAIR_stripped.nii.gz already exists
# # 250 Applying skull mask to 8779475_T1_registered.nii.gz...
# 8779475_T1_stripped.nii.gz already exists
# # 250 Applying skull mask to 8779475_T2_registered.nii.gz...
# 8779475_T2_stripped.nii.gz already exists
# # 250 Applying skull mask to 8779475_WB_registered.nii.gz...
# 8779475_WB_stripped.nii.gz already exists
# # 251 Applying skull mask to 8780276_3D_FLAIR_registered.nii.gz...
# 8780276_3D_FLAIR_stripped.nii.gz already exists
# # 251 Applying skull mask to 8780276_BB_registered.nii.gz...
# 8780276_BB_stripped.nii.gz already exists
# # 251 Applying skull mask to 8780276_FLAIR_registered.nii.gz...
# 8780276_FLAIR_stripped.nii.gz already exists
# # 251 Applying skull mask to 8780276_T1_registered.nii.gz...
# 8780276_T1_stripped.nii.gz already exists
# # 251 Applying skull mask to 8780276_T2_registered.nii.gz...
# 8780276_T2_stripped.nii.gz already exists
# # 251 Applying skull mask to 8780276_WB_registered.nii.gz...
# 8780276_WB_stripped.nii.gz already exists
# # 252 Applying skull mask to 8785546_3D_FLAIR_registered.nii.gz...
# 8785546_3D_FLAIR_stripped.nii.gz already exists
# # 252 Applying skull mask to 8785546_BB_registered.nii.gz...
# 8785546_BB_stripped.nii.gz already exists
# # 252 Applying skull mask to 8785546_FLAIR_registered.nii.gz...
# 8785546_FLAIR_stripped.nii.gz already exists
# # 252 Applying skull mask to 8785546_T1_registered.nii.gz...
# 8785546_T1_stripped.nii.gz already exists
# # 252 Applying skull mask to 8785546_T2_registered.nii.gz...
# 8785546_T2_stripped.nii.gz already exists
# # 252 Applying skull mask to 8785546_WB_registered.nii.gz...
# 8785546_WB_stripped.nii.gz already exists
# # 253 Applying skull mask to 8790376_3D_FLAIR_registered.nii.gz...
# 8790376_3D_FLAIR_stripped.nii.gz already exists
# # 253 Applying skull mask to 8790376_BB_registered.nii.gz...
# 8790376_BB_stripped.nii.gz already exists
# # 253 Applying skull mask to 8790376_FLAIR_registered.nii.gz...
# 8790376_FLAIR_stripped.nii.gz already exists
# # 253 Applying skull mask to 8790376_T1_registered.nii.gz...
# 8790376_T1_stripped.nii.gz already exists
# # 253 Applying skull mask to 8790376_T2_registered.nii.gz...
# 8790376_T2_stripped.nii.gz already exists
# # 253 Applying skull mask to 8790376_WB_registered.nii.gz...
# 8790376_WB_stripped.nii.gz already exists
# # 254 Applying skull mask to 8793858_3D_FLAIR_registered.nii.gz...
# 8793858_3D_FLAIR_stripped.nii.gz already exists
# # 254 Applying skull mask to 8793858_BB_registered.nii.gz...
# 8793858_BB_stripped.nii.gz already exists
# # 254 Applying skull mask to 8793858_FLAIR_registered.nii.gz...
# 8793858_FLAIR_stripped.nii.gz already exists
# # 254 Applying skull mask to 8793858_T1_registered.nii.gz...
# 8793858_T1_stripped.nii.gz already exists
# # 254 Applying skull mask to 8793858_T2_registered.nii.gz...
# 8793858_T2_stripped.nii.gz already exists
# # 254 Applying skull mask to 8793858_WB_registered.nii.gz...
# 8793858_WB_stripped.nii.gz already exists
# # 255 Applying skull mask to 8794654_3D_FLAIR_registered.nii.gz...
# 8794654_3D_FLAIR_stripped.nii.gz already exists
# # 255 Applying skull mask to 8794654_BB_registered.nii.gz...
# 8794654_BB_stripped.nii.gz already exists
# # 255 Applying skull mask to 8794654_FLAIR_registered.nii.gz...
# 8794654_FLAIR_stripped.nii.gz already exists
# # 255 Applying skull mask to 8794654_T1_registered.nii.gz...
# 8794654_T1_stripped.nii.gz already exists
# # 255 Applying skull mask to 8794654_T2_registered.nii.gz...
# 8794654_T2_stripped.nii.gz already exists
# # 255 Applying skull mask to 8794654_WB_registered.nii.gz...
# 8794654_WB_stripped.nii.gz already exists
# # 256 Applying skull mask to 8799587_3D_FLAIR_registered.nii.gz...
# 8799587_3D_FLAIR_stripped.nii.gz already exists
# # 256 Applying skull mask to 8799587_BB_registered.nii.gz...
# 8799587_BB_stripped.nii.gz already exists
# # 256 Applying skull mask to 8799587_FLAIR_registered.nii.gz...
# 8799587_FLAIR_stripped.nii.gz already exists
# # 256 Applying skull mask to 8799587_T1_registered.nii.gz...
# 8799587_T1_stripped.nii.gz already exists
# # 256 Applying skull mask to 8799587_T2_registered.nii.gz...
# 8799587_T2_stripped.nii.gz already exists
# # 256 Applying skull mask to 8799587_WB_registered.nii.gz...
# 8799587_WB_stripped.nii.gz already exists
# # 257 Applying skull mask to 8803725_3D_FLAIR_registered.nii.gz...
# 8803725_3D_FLAIR_stripped.nii.gz already exists
# # 257 Applying skull mask to 8803725_BB_registered.nii.gz...
# 8803725_BB_stripped.nii.gz already exists
# # 257 Applying skull mask to 8803725_FLAIR_registered.nii.gz...
# 8803725_FLAIR_stripped.nii.gz already exists
# # 257 Applying skull mask to 8803725_T1_registered.nii.gz...
# 8803725_T1_stripped.nii.gz already exists
# # 257 Applying skull mask to 8803725_T2_registered.nii.gz...
# 8803725_T2_stripped.nii.gz already exists
# # 257 Applying skull mask to 8803725_WB_registered.nii.gz...
# 8803725_WB_stripped.nii.gz already exists
# # 258 Applying skull mask to 8814110_3D_FLAIR_registered.nii.gz...
# /home/sc-mlsg/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# /home/sc-mlsg/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# # 258 Applying skull mask to 8814110_BB_registered.nii.gz...
# # 258 Applying skull mask to 8814110_FLAIR_registered.nii.gz...
# # 258 Applying skull mask to 8814110_T1_registered.nii.gz...
# # 258 Applying skull mask to 8814110_T2_registered.nii.gz...
# # 258 Applying skull mask to 8814110_WB_registered.nii.gz...
# # 259 Applying skull mask to 8822304_3D_FLAIR_registered.nii.gz...
# # 259 Applying skull mask to 8822304_BB_registered.nii.gz...
# # 259 Applying skull mask to 8822304_FLAIR_registered.nii.gz...
# # 259 Applying skull mask to 8822304_T1_registered.nii.gz...
# # 259 Applying skull mask to 8822304_T2_registered.nii.gz...
# # 259 Applying skull mask to 8822304_WB_registered.nii.gz...
# # 260 Applying skull mask to 8824792_3D_FLAIR_registered.nii.gz...
# # 260 Applying skull mask to 8824792_BB_registered.nii.gz...
# # 260 Applying skull mask to 8824792_FLAIR_registered.nii.gz...
# # 260 Applying skull mask to 8824792_T1_registered.nii.gz...
# # 260 Applying skull mask to 8824792_T2_registered.nii.gz...
# # 260 Applying skull mask to 8824792_WB_registered.nii.gz...
# # 261 Applying skull mask to 8844889_3D_FLAIR_registered.nii.gz...
# # 261 Applying skull mask to 8844889_BB_registered.nii.gz...
# # 261 Applying skull mask to 8844889_FLAIR_registered.nii.gz...
# # 261 Applying skull mask to 8844889_T1_registered.nii.gz...
# # 261 Applying skull mask to 8844889_T2_registered.nii.gz...
# # 261 Applying skull mask to 8844889_WB_registered.nii.gz...
# # 262 Applying skull mask to 8857629_3D_FLAIR_registered.nii.gz...
# # 262 Applying skull mask to 8857629_BB_registered.nii.gz...
# # 262 Applying skull mask to 8857629_FLAIR_registered.nii.gz...
# # 262 Applying skull mask to 8857629_T1_registered.nii.gz...
# # 262 Applying skull mask to 8857629_T2_registered.nii.gz...
# # 262 Applying skull mask to 8857629_WB_registered.nii.gz...
# # 263 Applying skull mask to 8862948_3D_FLAIR_registered.nii.gz...
# # 263 Applying skull mask to 8862948_BB_registered.nii.gz...
# # 263 Applying skull mask to 8862948_FLAIR_registered.nii.gz...
# # 263 Applying skull mask to 8862948_T1_registered.nii.gz...
# # 263 Applying skull mask to 8862948_T2_registered.nii.gz...
# # 263 Applying skull mask to 8862948_WB_registered.nii.gz...
# # 264 Applying skull mask to 9039968_3D_FLAIR_registered.nii.gz...
# # 264 Applying skull mask to 9039968_BB_registered.nii.gz...
# # 264 Applying skull mask to 9039968_FLAIR_registered.nii.gz...
# # 264 Applying skull mask to 9039968_T1_registered.nii.gz...
# # 264 Applying skull mask to 9039968_T2_registered.nii.gz...
# # 264 Applying skull mask to 9039968_WB_registered.nii.gz...
# # 265 Applying skull mask to 9113641_3D_FLAIR_registered.nii.gz...
# # 265 Applying skull mask to 9113641_BB_registered.nii.gz...
# # 265 Applying skull mask to 9113641_FLAIR_registered.nii.gz...
# # 265 Applying skull mask to 9113641_T1_registered.nii.gz...
# # 265 Applying skull mask to 9113641_T2_registered.nii.gz...
# # 265 Applying skull mask to 9113641_WB_registered.nii.gz...
# Finished!
# {}

# %%
# 6) z-score normalization
total = 0
for (path, dirs, files) in os.walk(strippedDir):
    for file in files:
        try:
            total += 1
            print("Z-score normalization: #{}, {}".format(total, file))
            pt = path.split(os.path.sep)[-1]
            newfilename = file.split(".")[0] + "_znormed.nii.gz"
            znorm_outPath = get_outpath(znormedDir, pt, newfilename)
            if znorm_outPath is None:
                continue
            
            seq = find_seq(file)
            if seq == "ADC":
                print("ADC, copying file...")
                img_nii = nib.load(os.path.join(path, file))
                newfilename = file.split(".")[0] + ".nii.gz"
                nib.save(img_nii, os.path.join(znormedDir, pt, newfilename))
                continue
            img_nii = nib.load(os.path.join(path, file))
            img_data = img_nii.get_data()
            mean, std = np.mean(img_data), np.std(img_data)
            normalized = nib.Nifti1Image((img_data - mean) / std, img_nii.affine, img_nii.header)
            nib.save(normalized, znorm_outPath)
        except Exception as e:
            print(path, file)
            print(e)
# Out:
# Z-score normalization: #1, 8355900_T2_registered.nii.gz
# /home/sc-mlsg/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# Z-score normalization: #2, 8355900_T1C_registered.nii.gz
# Z-score normalization: #3, 8704204_T1C_registered.nii.gz
# Z-score normalization: #4, 8704204_T2_registered.nii.gz
# Z-score normalization: #5, 8445407_T1C_registered.nii.gz
# Z-score normalization: #6, 8445407_T2_registered.nii.gz
# Z-score normalization: #7, 5329806_T1C_registered.nii.gz
# Z-score normalization: #8, 5329806_T2_registered.nii.gz
# Z-score normalization: #9, 5165936_T1C_registered.nii.gz
# Z-score normalization: #10, 5165936_T2_registered.nii.gz
# Z-score normalization: #11, 4315438_T1C_registered.nii.gz
# Z-score normalization: #12, 4315438_T2_registered.nii.gz
# Z-score normalization: #13, 10088264_T2_registered.nii.gz
# Z-score normalization: #14, 10088264_T1C_registered.nii.gz
# Z-score normalization: #15, 5764412_T1C_registered.nii.gz
# Z-score normalization: #16, 5764412_T2_registered.nii.gz
# Z-score normalization: #17, 5584298_T1C_registered.nii.gz
# Z-score normalization: #18, 5584298_T2_registered.nii.gz
# Z-score normalization: #19, 7793380_T1C_registered.nii.gz
# Z-score normalization: #20, 7793380_T2_registered.nii.gz
# Z-score normalization: #21, 8274048_T1C_registered.nii.gz
# Z-score normalization: #22, 8274048_T2_registered.nii.gz
# Z-score normalization: #23, 5297962_T2_registered.nii.gz
# Z-score normalization: #24, 5297962_T1C_registered.nii.gz
# Z-score normalization: #25, 7388494_T2_registered.nii.gz
# Z-score normalization: #26, 7388494_T1C_registered.nii.gz
# Z-score normalization: #27, 7940665_T2_registered.nii.gz
# Z-score normalization: #28, 7940665_T1C_registered.nii.gz
# Z-score normalization: #29, 5870222_T1C_registered.nii.gz
# Z-score normalization: #30, 5870222_T2_registered.nii.gz
# Z-score normalization: #31, 6475512_T2_registered.nii.gz
# Z-score normalization: #32, 6475512_T1C_registered.nii.gz
# Z-score normalization: #33, 3016835_T2_registered.nii.gz
# Z-score normalization: #34, 3016835_T1C_registered.nii.gz
# Z-score normalization: #35, 8091567_T2_registered.nii.gz
# Z-score normalization: #36, 8091567_T1C_registered.nii.gz
# Z-score normalization: #37, 8462147_T2_registered.nii.gz
# Z-score normalization: #38, 8462147_T1C_registered.nii.gz
# Z-score normalization: #39, 5545997_T1C_registered.nii.gz
# Z-score normalization: #40, 5545997_T2_registered.nii.gz
# Z-score normalization: #41, 3332002_T2_registered.nii.gz
# Z-score normalization: #42, 3332002_T1C_registered.nii.gz
# Z-score normalization: #43, 5482785_T1C_registered.nii.gz
# Z-score normalization: #44, 5482785_T2_registered.nii.gz
# Z-score normalization: #45, 8573949_T2_registered.nii.gz
# Z-score normalization: #46, 8573949_T1C_registered.nii.gz
# Z-score normalization: #47, 4352863_T2_registered.nii.gz
# Z-score normalization: #48, 4352863_T1C_registered.nii.gz
# Z-score normalization: #49, 5232890_T1C_registered.nii.gz
# Z-score normalization: #50, 5232890_T2_registered.nii.gz
# Z-score normalization: #51, 8854505_T2_registered.nii.gz
# Z-score normalization: #52, 8854505_T1C_registered.nii.gz
# Z-score normalization: #53, 8032803_T2_registered.nii.gz
# Z-score normalization: #54, 8032803_T1C_registered.nii.gz
# Z-score normalization: #55, 3802982_T2_registered.nii.gz
# Z-score normalization: #56, 3802982_T1C_registered.nii.gz
# Z-score normalization: #57, 3819641_T2_registered.nii.gz
# Z-score normalization: #58, 3819641_T1C_registered.nii.gz
# Z-score normalization: #59, 5840185_T1C_registered.nii.gz
# Z-score normalization: #60, 5840185_T2_registered.nii.gz
# Z-score normalization: #61, 8167279_T1C_registered.nii.gz
# Z-score normalization: #62, 8167279_T2_registered.nii.gz
# Z-score normalization: #63, 7618332_T1C_registered.nii.gz
# Z-score normalization: #64, 7618332_T2_registered.nii.gz
# Z-score normalization: #65, 24237_T1C_registered.nii.gz
# Z-score normalization: #66, 24237_T2_registered.nii.gz
# Z-score normalization: #67, 7837811_T1C_registered.nii.gz
# Z-score normalization: #68, 7837811_T2_registered.nii.gz
# Z-score normalization: #69, 5879269_T1C_registered.nii.gz
# Z-score normalization: #70, 5879269_T2_registered.nii.gz
# Z-score normalization: #71, 5727339_T2_registered.nii.gz
# Z-score normalization: #72, 5727339_T1C_registered.nii.gz
# Z-score normalization: #73, 7547961_T1C_registered.nii.gz
# Z-score normalization: #74, 7547961_T2_registered.nii.gz
# Z-score normalization: #75, 10020902_T1C_registered.nii.gz
# Z-score normalization: #76, 10020902_T2_registered.nii.gz
# Z-score normalization: #77, 8796872_T1C_registered.nii.gz
# Z-score normalization: #78, 8796872_T2_registered.nii.gz
# Z-score normalization: #79, 8688717_T2_registered.nii.gz
# Z-score normalization: #80, 8688717_T1C_registered.nii.gz
# Z-score normalization: #81, 7915638_T1C_registered.nii.gz
# Z-score normalization: #82, 7915638_T2_registered.nii.gz
# Z-score normalization: #83, 8389249_T2_registered.nii.gz
# Z-score normalization: #84, 8389249_T1C_registered.nii.gz
# Z-score normalization: #85, 8188316_T2_registered.nii.gz
# Z-score normalization: #86, 8188316_T1C_registered.nii.gz
# Z-score normalization: #87, 8293084_T1C_registered.nii.gz
# Z-score normalization: #88, 8293084_T2_registered.nii.gz
# Z-score normalization: #89, 5185528_T2_registered.nii.gz
# Z-score normalization: #90, 5185528_T1C_registered.nii.gz
# Z-score normalization: #91, 5148241_T2_registered.nii.gz
# Z-score normalization: #92, 5148241_T1C_registered.nii.gz
# Z-score normalization: #93, 4294621_T1C_registered.nii.gz
# Z-score normalization: #94, 4294621_T2_registered.nii.gz
# Z-score normalization: #95, 5782342_T2_registered.nii.gz
# Z-score normalization: #96, 5782342_T1C_registered.nii.gz
# Z-score normalization: #97, 7648996_T2_registered.nii.gz
# Z-score normalization: #98, 7648996_T1C_registered.nii.gz
# Z-score normalization: #99, 8192913_T2_registered.nii.gz
# Z-score normalization: #100, 8192913_T1C_registered.nii.gz
# Z-score normalization: #101, 7484329_T2_registered.nii.gz
# Z-score normalization: #102, 7484329_T1C_registered.nii.gz
# Z-score normalization: #103, 5247634_T1C_registered.nii.gz
# Z-score normalization: #104, 5247634_T2_registered.nii.gz
# Z-score normalization: #105, 8166115_T2_registered.nii.gz
# Z-score normalization: #106, 8166115_T1C_registered.nii.gz
# Z-score normalization: #107, 890950_T2_registered.nii.gz
# Z-score normalization: #108, 890950_T1C_registered.nii.gz
# Z-score normalization: #109, 5131557_T2_registered.nii.gz
# Z-score normalization: #110, 5131557_T1C_registered.nii.gz
# Z-score normalization: #111, 7409183_T2_registered.nii.gz
# Z-score normalization: #112, 7409183_T1C_registered.nii.gz
# Z-score normalization: #113, 8573185_T1C_registered.nii.gz
# Z-score normalization: #114, 8573185_T2_registered.nii.gz
# Z-score normalization: #115, 8545834_T2_registered.nii.gz
# Z-score normalization: #116, 8545834_T1C_registered.nii.gz
# Z-score normalization: #117, 10176016_T1C_registered.nii.gz
# Z-score normalization: #118, 10176016_T2_registered.nii.gz
# Z-score normalization: #119, 10162022_T2_registered.nii.gz
# Z-score normalization: #120, 10162022_T1C_registered.nii.gz
# Z-score normalization: #121, 7427402_T2_registered.nii.gz
# Z-score normalization: #122, 7427402_T1C_registered.nii.gz
# Z-score normalization: #123, 7460701_T1C_registered.nii.gz
# Z-score normalization: #124, 7460701_T2_registered.nii.gz
# Z-score normalization: #125, 5162636_T2_registered.nii.gz
# Z-score normalization: #126, 5162636_T1C_registered.nii.gz
# Z-score normalization: #127, 5379798_T1C_registered.nii.gz
# Z-score normalization: #128, 5379798_T2_registered.nii.gz
# Z-score normalization: #129, 8516487_T2_registered.nii.gz
# Z-score normalization: #130, 8516487_T1C_registered.nii.gz
# Z-score normalization: #131, 2752458_T2_registered.nii.gz
# Z-score normalization: #132, 2752458_T1C_registered.nii.gz
# Z-score normalization: #133, 8469528_T1C_registered.nii.gz
# Z-score normalization: #134, 8469528_T2_registered.nii.gz
# Z-score normalization: #135, 5840592_T1C_registered.nii.gz
# Z-score normalization: #136, 5840592_T2_registered.nii.gz
